# %% [markdown]
# # 1.09 Debugging run_benchmark()

# %%
import os
import warnings

# Suppress TensorFlow messages
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # 0=all, 1=info, 2=warnings, 3=errors only
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"  # Disable oneDNN optimizations messages

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from datetime import datetime

# Get date in ISO 8601 format (YYYY-MM-DD)
today_iso = datetime.now().strftime("%Y-%m-%d")
print(today_iso)  # Output: 2025-08-27

# Get date and time in ISO 8601 format
today_datetime_iso = datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
print(today_datetime_iso)  # Output: 2025-08-27T17:32:45
# Out:
# 2025-08-27
# 2025-08-27T17:53:00

# %%
from src.tuning.benchmark import run_benchmark

run_config = {
    "timestamp": "",
    "yaml_path": "",
    "interval": "",
    "patient_numbers": [],
    "scorers": {},
    "cv_type": {},
    "models_count": [],
    "impute_methods": {},
    "time_taken": 0,
    "x_features": [],
    "y_features": [],
    "initial_window": 0,
    "step_length": 0,
    "steps_per_hour": 0,
    "hours_to_forecast": 0,
}

timestamp = "2025-03-20_18-54-56"
yaml_path = "./src/tuning/configs/0_naive_05min.yaml"
config = {
    "steps_per_hour": 12,
    "is_5min": True,
}
yaml_name = yaml_path.split("/")[-1].replace(".yaml", "")
results_dir = "./results"
raw_output_file_path = (
    "./results/raw/tests/"
    + datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
    + "_0_naive_05min.csv"
)
processed_dir = "./results/processed/tests/" + datetime.now().strftime(
    "%Y-%m-%dT%H:%M:%S"
)
x_features = [
    "hr_bpm",
    "steps",
    "cals",
    "cob",
    "carb_availability",
    "insulin_availability",
    "iob",
]
y_features = ["bg_mM"]

# %%
run_benchmark(
    data_source_name="kaggle_brisT1D",
    y_features=y_features,
    x_features=x_features,
    initial_cv_window=config["steps_per_hour"] * 24 * 3,  # 3 days
    cv_step_length=config["steps_per_hour"] * 24 * 6,  # 6 days
    steps_per_hour=config["steps_per_hour"],
    hours_to_forecast=6,
    yaml_path=yaml_path,
    bg_method="linear",
    hr_method="linear",
    step_method="constant",
    cal_method="constant",
    results_dir=results_dir,
    cores_num=1,  # 1 core is sufficient for testing
    n_patients=2,  # 2 patients are sufficient for testing
    is_5min=config["is_5min"],  # 5-minute interval patients
    description="Test benchmark",
    timestamp=timestamp,
)
# Out:
# 2025-08-27T18:02:38 - _process_raw_train_data: Processing train data. This may take a while...
# 2025-08-27T18:02:39 - Processing 9 patients:
# 2025-08-27T18:02:39 - Processing 9 patients:
# 2025-08-27T18:02:39 - Running process_single_patient_data(),
# 			Processing patient p01 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:39 - 	Inputed patient start time: 06:10:00
# 2025-08-27T18:02:39 - Running process_single_patient_data(),
# 			Processing patient p01 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:39 - 	Inputed patient start time: 06:10:00
# 2025-08-27T18:02:39 - Running process_single_patient_data(),
# 			Processing patient p02 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:39 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:02:39 - Running process_single_patient_data(),
# 			Processing patient p02 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:39 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:02:39 - Running process_single_patient_data(),
# 			Processing patient p03 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:39 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:02:39 - Running process_single_patient_data(),
# 			Processing patient p03 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:39 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end date: 2024-03-31 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start time: 06:10:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end time: 23:50:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end date: 2024-03-31 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start time: 06:10:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end time: 23:50:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:39 - 	Created columns for patient p01 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	Result patient start time: 06:10:00
# 2025-08-27T18:02:39 - 	Length of dates: 8459
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:39 - 	Created columns for patient p01 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	Result patient start time: 06:10:00
# 2025-08-27T18:02:39 - 	Length of dates: 8459
# 2025-08-27T18:02:39 - 	Length of times: 8459
# 2025-08-27T18:02:39 - 	Length of times: 8459
# 2025-08-27T18:02:39 - ==============================
# 2025-08-27T18:02:39 - Preprocessing patient p01
# 2025-08-27T18:02:39 - ==============================
# 2025-08-27T18:02:39 - derive_features(): Deriving features...
# 2025-08-27T18:02:39 - ==============================
# 2025-08-27T18:02:39 - Preprocessing patient p01
# 2025-08-27T18:02:39 - ==============================
# 2025-08-27T18:02:39 - derive_features(): Deriving features...
# 2025-08-27T18:02:39 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:02:39 - 	Most common time interval: 15 minutes
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:02:39 - 	Most common time interval: 15 minutes
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:39 - 	Created columns for patient p02 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	Created columns for patient p02 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	Result patient start time: 06:05:00
# 2025-08-27T18:02:39 - Post-ensure_regular_time_intervals():
# 			Patient p01
# 			 - old index length: 8459,
# 			 - new index length: 8711
# 2025-08-27T18:02:39 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:39 - 	Length of dates: 25872
# 2025-08-27T18:02:39 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:39 - 	Result patient start time: 06:05:00
# 2025-08-27T18:02:39 - Post-ensure_regular_time_intervals():
# 			Patient p01
# 			 - old index length: 8459,
# 			 - new index length: 8711
# 2025-08-27T18:02:39 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:39 - 	Length of dates: 25872
# 2025-08-27T18:02:39 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:39 - 	Length of times: 25872
# 2025-08-27T18:02:39 - 	Processing glucose dynamics
# 2025-08-27T18:02:39 - 	Length of times: 25872
# 2025-08-27T18:02:39 - 	Processing glucose dynamics
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:39 - 	Created columns for patient p03 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:39 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:39 - 	Created columns for patient p03 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:39 - 	Result patient start time: 06:05:00
# 2025-08-27T18:02:39 - 	Length of dates: 26028
# 2025-08-27T18:02:39 - 	Length of times: 26028
# 2025-08-27T18:02:39 - 	Result patient start time: 06:05:00
# 2025-08-27T18:02:39 - 	Length of dates: 26028
# 2025-08-27T18:02:39 - 	Length of times: 26028
# 2025-08-27T18:02:40 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:40 - 	Processing insulin dynamics
# 2025-08-27T18:02:40 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:40 - 	Processing insulin dynamics
# 2025-08-27T18:02:40 - ==============================
# 2025-08-27T18:02:40 - Preprocessing patient p02
# 2025-08-27T18:02:40 - ==============================
# 2025-08-27T18:02:40 - derive_features(): Deriving features...
# 2025-08-27T18:02:40 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:40 - ==============================
# 2025-08-27T18:02:40 - Preprocessing patient p02
# 2025-08-27T18:02:40 - ==============================
# 2025-08-27T18:02:40 - derive_features(): Deriving features...
# 2025-08-27T18:02:40 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:40 - 	Most common time interval: 5 minutes
# 2025-08-27T18:02:40 - Post-ensure_regular_time_intervals():
# 			Patient p02
# 			 - old index length: 25872,
# 			 - new index length: 26423
# 2025-08-27T18:02:40 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:40 - 	Most common time interval: 5 minutes
# 2025-08-27T18:02:40 - Post-ensure_regular_time_intervals():
# 			Patient p02
# 			 - old index length: 25872,
# 			 - new index length: 26423
# 2025-08-27T18:02:40 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:40 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:40 - 	Processing glucose dynamics
# 2025-08-27T18:02:40 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:40 - 	Processing glucose dynamics
# 2025-08-27T18:02:41 - ==============================
# 2025-08-27T18:02:41 - Preprocessing patient p03
# 2025-08-27T18:02:41 - ==============================
# 2025-08-27T18:02:41 - ==============================
# 2025-08-27T18:02:41 - Preprocessing patient p03
# 2025-08-27T18:02:41 - ==============================
# 2025-08-27T18:02:41 - derive_features(): Deriving features...
# 2025-08-27T18:02:41 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:41 - derive_features(): Deriving features...
# 2025-08-27T18:02:41 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:41 - 	Most common time interval: 5 minutes
# 2025-08-27T18:02:41 - 	Most common time interval: 5 minutes
# 2025-08-27T18:02:41 - Post-ensure_regular_time_intervals():
# 			Patient p03
# 			 - old index length: 26028,
# 			 - new index length: 26423
# 2025-08-27T18:02:41 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:41 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:41 - Post-ensure_regular_time_intervals():
# 			Patient p03
# 			 - old index length: 26028,
# 			 - new index length: 26423
# 2025-08-27T18:02:41 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:41 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:41 - 	Processing glucose dynamics
# 2025-08-27T18:02:41 - 	Processing glucose dynamics
# 2025-08-27T18:02:41 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:41 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:41 - 	Processing insulin dynamics
# 2025-08-27T18:02:41 - 	Processing insulin dynamics
# 2025-08-27T18:02:42 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:42 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:42 - 	Processing insulin dynamics
# 2025-08-27T18:02:42 - 	Processing insulin dynamics
# 2025-08-27T18:02:54 - 	Done deriving features.
#
# 2025-08-27T18:02:54 - processed_results: Successfully processed patient p01
# 2025-08-27T18:02:54 - 	Done deriving features.
#
# 2025-08-27T18:02:54 - processed_results: Successfully processed patient p01
# 2025-08-27T18:02:54 - Running process_single_patient_data(),
# 			Processing patient p04 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:54 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:02:54 - Running process_single_patient_data(),
# 			Processing patient p04 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:02:54 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result end date: 2024-03-27 00:00:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:54 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:54 - 	Created columns for patient p04 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:54 - 	Result patient start time: 06:05:00
# 2025-08-27T18:02:54 - 	Length of dates: 24686
# 2025-08-27T18:02:54 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result end date: 2024-03-27 00:00:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:02:54 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:02:54 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:02:54 - 	Created columns for patient p04 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:02:54 - 	Result patient start time: 06:05:00
# 2025-08-27T18:02:54 - 	Length of dates: 24686
# 2025-08-27T18:02:54 - 	Length of times: 24686
# 2025-08-27T18:02:54 - 	Length of times: 24686
# 2025-08-27T18:02:55 - ==============================
# 2025-08-27T18:02:55 - Preprocessing patient p04
# 2025-08-27T18:02:55 - ==============================
# 2025-08-27T18:02:55 - derive_features(): Deriving features...
# 2025-08-27T18:02:55 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:55 - ==============================
# 2025-08-27T18:02:55 - Preprocessing patient p04
# 2025-08-27T18:02:55 - ==============================
# 2025-08-27T18:02:55 - derive_features(): Deriving features...
# 2025-08-27T18:02:55 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:02:55 - 	Most common time interval: 5 minutes
# 2025-08-27T18:02:55 - Post-ensure_regular_time_intervals():
# 			Patient p04
# 			 - old index length: 24686,
# 			 - new index length: 24983
# 2025-08-27T18:02:55 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:55 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:55 - 	Most common time interval: 5 minutes
# 2025-08-27T18:02:55 - Post-ensure_regular_time_intervals():
# 			Patient p04
# 			 - old index length: 24686,
# 			 - new index length: 24983
# 2025-08-27T18:02:55 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:02:55 - 	Creating COB and carb availability columns...
# 2025-08-27T18:02:55 - 	Processing glucose dynamics
# 2025-08-27T18:02:55 - 	Processing glucose dynamics
# 2025-08-27T18:02:55 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:55 - 	Processing insulin dynamics
# 2025-08-27T18:02:55 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:02:55 - 	Processing insulin dynamics
# 2025-08-27T18:03:32 - 	Done deriving features.
#
# 2025-08-27T18:03:32 - 	Done deriving features.
#
# 2025-08-27T18:03:32 - processed_results: Successfully processed patient p04
# 2025-08-27T18:03:32 - Running process_single_patient_data(),
# 			Processing patient p05 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:32 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:03:32 - processed_results: Successfully processed patient p04
# 2025-08-27T18:03:32 - Running process_single_patient_data(),
# 			Processing patient p05 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:32 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result end time: 23:50:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:32 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:32 - 	Created columns for patient p05 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Result end time: 23:50:00
# 2025-08-27T18:03:32 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:32 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:32 - 	Created columns for patient p05 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:32 - 	Result patient start time: 06:05:00
# 2025-08-27T18:03:32 - 	Result patient start time: 06:05:00
# 2025-08-27T18:03:32 - 	Length of dates: 8288
# 2025-08-27T18:03:32 - 	Length of times: 8288
# 2025-08-27T18:03:32 - 	Length of dates: 8288
# 2025-08-27T18:03:32 - 	Length of times: 8288
# 2025-08-27T18:03:33 - ==============================
# 2025-08-27T18:03:33 - Preprocessing patient p05
# 2025-08-27T18:03:33 - ==============================
# 2025-08-27T18:03:33 - derive_features(): Deriving features...
# 2025-08-27T18:03:33 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:33 - 	Most common time interval: 15 minutes
# 2025-08-27T18:03:33 - ==============================
# 2025-08-27T18:03:33 - Preprocessing patient p05
# 2025-08-27T18:03:33 - ==============================
# 2025-08-27T18:03:33 - derive_features(): Deriving features...
# 2025-08-27T18:03:33 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:33 - 	Most common time interval: 15 minutes
# 2025-08-27T18:03:33 - Post-ensure_regular_time_intervals():
# 			Patient p05
# 			 - old index length: 8288,
# 			 - new index length: 8808
# 2025-08-27T18:03:33 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:33 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:33 - 	Processing glucose dynamics
# 2025-08-27T18:03:33 - Post-ensure_regular_time_intervals():
# 			Patient p05
# 			 - old index length: 8288,
# 			 - new index length: 8808
# 2025-08-27T18:03:33 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:33 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:33 - 	Processing glucose dynamics
# 2025-08-27T18:03:33 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:33 - 	Processing insulin dynamics
# 2025-08-27T18:03:33 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:33 - 	Processing insulin dynamics
# 2025-08-27T18:03:46 - 	Done deriving features.
#
# 2025-08-27T18:03:46 - processed_results: Successfully processed patient p05
# 2025-08-27T18:03:46 - 	Done deriving features.
#
# 2025-08-27T18:03:46 - processed_results: Successfully processed patient p05
# 2025-08-27T18:03:46 - Running process_single_patient_data(),
# 			Processing patient p06 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:46 - 	Inputed patient start time: 10:25:00
# 2025-08-27T18:03:46 - Running process_single_patient_data(),
# 			Processing patient p06 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:46 - 	Inputed patient start time: 10:25:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result start time: 10:25:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:46 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:46 - 	Created columns for patient p06 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:46 - 	Result patient start time: 10:25:00
# 2025-08-27T18:03:46 - 	Length of dates: 8383
# 2025-08-27T18:03:46 - 	Length of times: 8383
# 2025-08-27T18:03:46 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result start time: 10:25:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:03:46 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:46 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:46 - 	Created columns for patient p06 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:46 - 	Result patient start time: 10:25:00
# 2025-08-27T18:03:46 - 	Length of dates: 8383
# 2025-08-27T18:03:46 - 	Length of times: 8383
# 2025-08-27T18:03:46 - ==============================
# 2025-08-27T18:03:46 - Preprocessing patient p06
# 2025-08-27T18:03:46 - ==============================
# 2025-08-27T18:03:46 - derive_features(): Deriving features...
# 2025-08-27T18:03:46 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:46 - 	Most common time interval: 15 minutes
# 2025-08-27T18:03:46 - Post-ensure_regular_time_intervals():
# 			Patient p06
# 			 - old index length: 8383,
# 			 - new index length: 8791
# 2025-08-27T18:03:46 - ==============================
# 2025-08-27T18:03:46 - Preprocessing patient p06
# 2025-08-27T18:03:46 - ==============================
# 2025-08-27T18:03:46 - derive_features(): Deriving features...
# 2025-08-27T18:03:46 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:46 - 	Most common time interval: 15 minutes
# 2025-08-27T18:03:46 - Post-ensure_regular_time_intervals():
# 			Patient p06
# 			 - old index length: 8383,
# 			 - new index length: 8791
# 2025-08-27T18:03:46 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:46 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:46 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:46 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:46 - 	Processing glucose dynamics
# 2025-08-27T18:03:46 - 	Processing glucose dynamics
# 2025-08-27T18:03:46 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:46 - 	Processing insulin dynamics
# 2025-08-27T18:03:46 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:46 - 	Processing insulin dynamics
# 2025-08-27T18:03:58 - 	Done deriving features.
#
# 2025-08-27T18:03:58 - 	Done deriving features.
#
# 2025-08-27T18:03:58 - Running process_single_patient_data(),
# 			Processing patient p10 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:58 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:03:58 - processed_results: Successfully processed patient p02
# 2025-08-27T18:03:58 - Running process_single_patient_data(),
# 			Processing patient p10 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:58 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:03:58 - processed_results: Successfully processed patient p02
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end date: 2024-03-30 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end date: 2024-03-30 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end time: 20:15:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:58 - 	Created columns for patient p10 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	Result patient start time: 06:05:00
# 2025-08-27T18:03:58 - 	Length of dates: 25454
# 2025-08-27T18:03:58 - 	Length of times: 25454
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end time: 20:15:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:58 - 	Created columns for patient p10 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	Result patient start time: 06:05:00
# 2025-08-27T18:03:58 - 	Length of dates: 25454
# 2025-08-27T18:03:58 - 	Length of times: 25454
# 2025-08-27T18:03:58 - 	Done deriving features.
#
# 2025-08-27T18:03:58 - 	Done deriving features.
#
# 2025-08-27T18:03:58 - processed_results: Successfully processed patient p03
# 2025-08-27T18:03:58 - Running process_single_patient_data(),
# 			Processing patient p11 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:58 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:03:58 - processed_results: Successfully processed patient p03
# 2025-08-27T18:03:58 - Running process_single_patient_data(),
# 			Processing patient p11 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:03:58 - 	Inputed patient start time: 06:05:00
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - Preprocessing patient p10
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - derive_features(): Deriving features...
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - Preprocessing patient p10
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - derive_features(): Deriving features...
# 2025-08-27T18:03:58 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:58 - 	Most common time interval: 5 minutes
# 2025-08-27T18:03:58 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:58 - 	Most common time interval: 5 minutes
# 2025-08-27T18:03:58 - Post-ensure_regular_time_intervals():
# 			Patient p10
# 			 - old index length: 25454,
# 			 - new index length: 25803
# 2025-08-27T18:03:58 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:58 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:58 - 	Processing glucose dynamics
# 2025-08-27T18:03:58 - Post-ensure_regular_time_intervals():
# 			Patient p10
# 			 - old index length: 25454,
# 			 - new index length: 25803
# 2025-08-27T18:03:58 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:58 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:58 - 	Processing glucose dynamics
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end date: 2024-03-29 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end date: 2024-03-29 00:00:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result start time: 06:05:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:58 - 	Created columns for patient p11 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	Result patient start time: 06:05:00
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:03:58 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:03:58 - 	Created columns for patient p11 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:03:58 - 	Result patient start time: 06:05:00
# 2025-08-27T18:03:58 - 	Length of dates: 24555
# 2025-08-27T18:03:58 - 	Length of times: 24555
# 2025-08-27T18:03:58 - 	Length of dates: 24555
# 2025-08-27T18:03:58 - 	Length of times: 24555
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - Preprocessing patient p11
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - Preprocessing patient p11
# 2025-08-27T18:03:58 - ==============================
# 2025-08-27T18:03:58 - derive_features(): Deriving features...
# 2025-08-27T18:03:58 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:58 - derive_features(): Deriving features...
# 2025-08-27T18:03:58 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:03:58 - 	Most common time interval: 5 minutes
# 2025-08-27T18:03:58 - 	Most common time interval: 5 minutes
# 2025-08-27T18:03:58 - Post-ensure_regular_time_intervals():
# 			Patient p11
# 			 - old index length: 24555,
# 			 - new index length: 25559
# 2025-08-27T18:03:58 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:58 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:58 - Post-ensure_regular_time_intervals():
# 			Patient p11
# 			 - old index length: 24555,
# 			 - new index length: 25559
# 2025-08-27T18:03:58 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:03:58 - 	Creating COB and carb availability columns...
# 2025-08-27T18:03:58 - 	Processing glucose dynamics
# 2025-08-27T18:03:58 - 	Processing glucose dynamics
# 2025-08-27T18:03:59 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:59 - 	Processing insulin dynamics
# 2025-08-27T18:03:59 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:59 - 	Processing insulin dynamics
# 2025-08-27T18:03:59 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:59 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:03:59 - 	Processing insulin dynamics
# 2025-08-27T18:03:59 - 	Processing insulin dynamics
# 2025-08-27T18:04:00 - 	Done deriving features.
#
# 2025-08-27T18:04:00 - processed_results: Successfully processed patient p06
# 2025-08-27T18:04:00 - 	Done deriving features.
#
# 2025-08-27T18:04:00 - processed_results: Successfully processed patient p06
# 2025-08-27T18:04:00 - Running process_single_patient_data(),
# 			Processing patient p12 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:04:00 - 	Inputed patient start time: 10:25:00
# 2025-08-27T18:04:00 - Running process_single_patient_data(),
# 			Processing patient p12 data...
# 			Patient start date: 2024-01-01
# 2025-08-27T18:04:00 - 	Inputed patient start time: 10:25:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result start time: 10:25:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result start time: 10:25:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Result end time: 23:55:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:04:00 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:04:00 - 	Created columns for patient p12 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:04:00 - 	Result patient start time: 10:25:00
# 2025-08-27T18:04:00 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-08-27T18:04:00 - 	create_dt_col() - Any NaT values in times? 0
# 2025-08-27T18:04:00 - 	Created columns for patient p12 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-08-27T18:04:00 - 	Result patient start time: 10:25:00
# 2025-08-27T18:04:00 - 	Length of dates: 25299
# 2025-08-27T18:04:00 - 	Length of times: 25299
# 2025-08-27T18:04:00 - 	Length of dates: 25299
# 2025-08-27T18:04:00 - 	Length of times: 25299
# 2025-08-27T18:04:00 - ==============================
# 2025-08-27T18:04:00 - Preprocessing patient p12
# 2025-08-27T18:04:00 - ==============================
# 2025-08-27T18:04:00 - derive_features(): Deriving features...
# 2025-08-27T18:04:00 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:04:00 - 	Most common time interval: 5 minutes
# 2025-08-27T18:04:00 - ==============================
# 2025-08-27T18:04:00 - Preprocessing patient p12
# 2025-08-27T18:04:00 - ==============================
# 2025-08-27T18:04:00 - derive_features(): Deriving features...
# 2025-08-27T18:04:00 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-08-27T18:04:00 - 	Most common time interval: 5 minutes
# 2025-08-27T18:04:00 - Post-ensure_regular_time_intervals():
# 			Patient p12
# 			 - old index length: 25299,
# 			 - new index length: 26371
# 2025-08-27T18:04:00 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:04:00 - 	Creating COB and carb availability columns...
# 2025-08-27T18:04:00 - 	Processing glucose dynamics
# 2025-08-27T18:04:00 - Post-ensure_regular_time_intervals():
# 			Patient p12
# 			 - old index length: 25299,
# 			 - new index length: 26371
# 2025-08-27T18:04:00 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-08-27T18:04:00 - 	Creating COB and carb availability columns...
# 2025-08-27T18:04:00 - 	Processing glucose dynamics
# 2025-08-27T18:04:01 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:04:01 - 	Processing insulin dynamics
# 2025-08-27T18:04:01 - 	Creating IOB and insulin availability columns...
# 2025-08-27T18:04:01 - 	Processing insulin dynamics
# 2025-08-27T18:04:26 - 	Done deriving features.
#
# 2025-08-27T18:04:26 - 	Done deriving features.
#
# 2025-08-27T18:04:26 - processed_results: Successfully processed patient p12
# 2025-08-27T18:04:26 - processed_results: Successfully processed patient p12
# 2025-08-27T18:04:38 - 	Done deriving features.
#
# 2025-08-27T18:04:38 - 	Done deriving features.
#
# 2025-08-27T18:04:38 - processed_results: Successfully processed patient p11
# 2025-08-27T18:04:38 - processed_results: Successfully processed patient p11
# 2025-08-27T18:04:47 - 	Done deriving features.
#
# 2025-08-27T18:04:47 - 	Done deriving features.
#
# 2025-08-27T18:04:47 - processed_results: Successfully processed patient p10
# 2025-08-27T18:04:47 - processed_results: Successfully processed patient p10
# 2025-08-27T18:04:47 - Done processing train data. Saving processed data to cache...
# 2025-08-27T18:04:47 - Done processing train data. Saving processed data to cache...
# 2025-08-27T18:04:47 - 	Saved processed train data for kaggle_brisT1D - patient: p01
# 2025-08-27T18:04:47 - 	Saved processed train data for kaggle_brisT1D - patient: p01
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p04
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p04
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p05
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p05
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p02
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p02
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p03
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p03
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p06
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p06
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p12
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p12
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p11
# 2025-08-27T18:04:48 - 	Saved processed train data for kaggle_brisT1D - patient: p11
# 2025-08-27T18:04:49 - 	Saved processed train data for kaggle_brisT1D - patient: p10
# 2025-08-27T18:04:49 - 	Saved processed train data for kaggle_brisT1D - patient: p10
# 2025-08-27T18:04:49 - Successfully processed and cached data for 9 patients
# 2025-08-27T18:04:49 - Successfully processed and cached data for 9 patients
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 run_benchmark(
#       2     data_source_name="kaggle_brisT1D",
#       3     y_features=y_features,
#       4     x_features=x_features,
#       5     initial_cv_window=config["steps_per_hour"] * 24 * 3,  # 3 days
#       6     cv_step_length=config["steps_per_hour"] * 24 * 6,  # 6 days
#       7     steps_per_hour=config["steps_per_hour"],
#       8     hours_to_forecast=6,
#       9     yaml_path=yaml_path,
#      10     bg_method="linear",
#      11     hr_method="linear",
#      12     step_method="constant",
#      13     cal_method="constant",
#      14     results_dir=results_dir,
#      15     cores_num=1,  # 1 core is sufficient for testing
#      16     n_patients=2,  # 2 patients are sufficient for testing
#      17     is_5min=config["is_5min"],  # 5-minute interval patients
#      18     description="Test benchmark",
#      19     timestamp=timestamp,
#      20 )
#
# File ~/nocturnal/src/tuning/benchmark.py:570, in run_benchmark(data_source_name, y_features, x_features, cv_type, validation_days, initial_cv_window, cv_step_length, steps_per_hour, hours_to_forecast, yaml_path, bg_method, hr_method, step_method, cal_method, results_dir, cores_num, is_5min, n_patients, description, timestamp)
#     555 save_init_config(
#     556     current_time=current_time,
#     557     validation_days=validation_days,
#    (...)    566     data_source_name=data_source_name,
#     567 )
#     569 # Get dataset loaders with imputed missing values
# --> 570 dataset_loaders = get_dataset_loaders(
#     571     data_source_name=data_source_name,
#     572     validation_days=validation_days,
#     573     x_features=x_features,
#     574     y_feature=y_features,
#     575     bg_method=bg_method,
#     576     hr_method=hr_method,
#     577     step_method=step_method,
#     578     cal_method=cal_method,
#     579     n_patients=n_patients,
#     580     is_5min=is_5min,
#     581 )
#     583 # ADD THE SCORERS HERE
#     584 scorers = [
#     585     # PinballLoss(),
#     586     MeanSquaredError(square_root=True),
#     587 ]
#
# File ~/nocturnal/src/tuning/benchmark.py:283, in get_dataset_loaders(data_source_name, validation_days, x_features, y_feature, bg_method, hr_method, step_method, cal_method, is_5min, n_patients)
#     281 df = loader.processed_data
#     282 # TODO: It is default of 20 days. Might need to change that
# --> 283 df, _ = get_train_validation_split(df, num_validation_days=validation_days)
#     285 # TODO: Impute Missing values for each columns
#     286 df = impute_missing_values(df, columns=x_features, bg_method=bg_method)
#
# File ~/nocturnal/src/data/preprocessing/time_processing.py:199, in get_train_validation_split(df, num_validation_days)
#     181 """
#     182 Split the data into train and validation sets based on complete days.
#     183
#    (...)    196         contains exactly num_validation_days of complete days
#     197 """
#     198 # Check if datetime is the index or a column
# --> 199 if "datetime" not in df.columns:
#     200     if df.index.name == "datetime" or isinstance(df.index, pd.DatetimeIndex):
#     201         # datetime is the index, reset it to a column
#     202         df = df.reset_index()
#
# AttributeError: 'dict' object has no attribute 'columns'
