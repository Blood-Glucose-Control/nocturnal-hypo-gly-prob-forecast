# %% [markdown]
# # Debugging Data Cleaning Workbook
#
# ## Purpose

# %%
from src.data.diabetes_datasets.data_loader import get_loader

loader = get_loader(
    data_source_name="kaggle_brisT1D",
    dataset_type="train",
    keep_columns=[
        "datetime",
        "p_num",
        "bg_mM",
        "hr_bpm",
        "steps",
        "cals",
        "cob",
        "carb_availability",
        "dose_units",
        "iob",
        "insulin_availability",
    ],
    use_cached=False,
    parallel=False,
)
# Out:
# 2025-08-20T18:40:40 - Processed cache not found or not used, processing raw data and saving to cache...
# 2025-08-20T18:40:40 - Raw data for kaggle_brisT1D already exists in cache
# 2025-08-20T18:40:48 - _process_raw_train_data: Processing train data. This may take a while...
# 2025-08-20T18:40:48 - Processing 9 patients in parallel:
# 2025-08-20T18:40:48 - 	 Converting time to datetime using start date: 2024-01-01 00:00:00
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p01
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p02
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p03
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p04
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p05
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p06
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p10
# 2025-08-20T18:40:48 - Stored pre-parallel DataFrame for patient p11
# 2025-08-20T18:40:49 - Stored pre-parallel DataFrame for patient p12
# 2025-08-20T18:40:49 - ==============================
# 2025-08-20T18:40:49 - Preprocessing patient p01
# 2025-08-20T18:40:49 - ==============================
#
# 2025-08-20T18:40:49 - Deriving features...
# 2025-08-20T18:40:49 - Filling in gaps...
# 2025-08-20T18:40:49 - Creating COB and carb availability columns...
# ========================
#  Processing patient p01 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p01 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:10:00
#
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-03-31 00:00:00
# 	 Result start time: 06:10:00
# 	 Result end time: 23:50:00
# 	 Result VERY End (last 5):
# 8454   2024-03-31
# 8455   2024-03-31
# 8456   2024-03-31
# 8457   2024-03-31
# 8458   2024-03-31
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p01 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:10:00
# Length of dates: 8459
# Length of times: 8459
# Post-ensure_datetime_index():
# 	Patient p01
# 	index: DatetimeIndex(['2024-01-01 06:10:00', '2024-01-01 06:25:00',
#                '2024-01-01 06:40:00', '2024-01-01 06:55:00',
#                '2024-01-01 07:10:00', '2024-01-01 07:25:00',
#                '2024-01-01 07:40:00', '2024-01-01 07:55:00',
#                '2024-01-01 08:10:00', '2024-01-01 08:25:00',
#                ...
#                '2024-03-31 21:35:00', '2024-03-31 21:50:00',
#                '2024-03-31 22:05:00', '2024-03-31 22:20:00',
#                '2024-03-31 22:35:00', '2024-03-31 22:50:00',
#                '2024-03-31 23:05:00', '2024-03-31 23:20:00',
#                '2024-03-31 23:35:00', '2024-03-31 23:50:00'],
#               dtype='datetime64[ns]', name='datetime', length=8459, freq=None)
# Most common time interval: 15 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p01
# 	 old index length: 8459,
# 	 new index length: 8711
# 2025-08-20T18:40:49 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:49 - Done deriving features.
# ========================
#  Processing patient p02 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p02 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:05:00
#
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-04-01 00:00:00
# 	 Result start time: 06:05:00
# 	 Result end time: 23:55:00
# 	 Result VERY End (last 5):
# 25867   2024-04-01
# 25868   2024-04-01
# 25869   2024-04-01
# 25870   2024-04-01
# 25871   2024-04-01
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p02 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:05:00
# Length of dates: 25872
# Length of times: 25872
# 2025-08-20T18:40:49 - ==============================
# 2025-08-20T18:40:49 - Preprocessing patient p02
# 2025-08-20T18:40:49 - ==============================
#
# 2025-08-20T18:40:49 - Deriving features...
# 2025-08-20T18:40:49 - Filling in gaps...
# 2025-08-20T18:40:49 - Creating COB and carb availability columns...
# 2025-08-20T18:40:49 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:49 - Done deriving features.
# Post-ensure_datetime_index():
# 	Patient p02
# 	index: DatetimeIndex(['2024-01-01 06:05:00', '2024-01-01 06:10:00',
#                '2024-01-01 06:15:00', '2024-01-01 06:20:00',
#                '2024-01-01 06:25:00', '2024-01-01 06:30:00',
#                '2024-01-01 06:35:00', '2024-01-01 06:40:00',
#                '2024-01-01 06:45:00', '2024-01-01 06:50:00',
#                ...
#                '2024-04-01 23:10:00', '2024-04-01 23:15:00',
#                '2024-04-01 23:20:00', '2024-04-01 23:25:00',
#                '2024-04-01 23:30:00', '2024-04-01 23:35:00',
#                '2024-04-01 23:40:00', '2024-04-01 23:45:00',
#                '2024-04-01 23:50:00', '2024-04-01 23:55:00'],
#               dtype='datetime64[ns]', name='datetime', length=25872, freq=None)
# Most common time interval: 5 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p02
# 	 old index length: 25872,
# 	 new index length: 26423
#
# ========================
#  Processing patient p03 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p03 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:05:00
# 2025-08-20T18:40:50 - ==============================
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-04-01 00:00:00
# 	 Result start time: 06:05:00
# 	 Result end time: 23:55:00
# 	 Result VERY End (last 5):
# 26023   2024-04-01
# 26024   2024-04-01
# 26025   2024-04-01
# 26026   2024-04-01
# 26027   2024-04-01
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p03 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:05:00
# Length of dates: 26028
# Length of times: 26028
# 2025-08-20T18:40:50 - Preprocessing patient p03
# 2025-08-20T18:40:50 - ==============================
#
# 2025-08-20T18:40:50 - Deriving features...
# 2025-08-20T18:40:50 - Filling in gaps...
# 2025-08-20T18:40:50 - Creating COB and carb availability columns...
# 2025-08-20T18:40:50 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:50 - Done deriving features.
# Post-ensure_datetime_index():
# 	Patient p03
# 	index: DatetimeIndex(['2024-01-01 06:05:00', '2024-01-01 06:10:00',
#                '2024-01-01 06:15:00', '2024-01-01 06:20:00',
#                '2024-01-01 06:25:00', '2024-01-01 06:30:00',
#                '2024-01-01 06:35:00', '2024-01-01 06:40:00',
#                '2024-01-01 06:45:00', '2024-01-01 06:50:00',
#                ...
#                '2024-04-01 23:10:00', '2024-04-01 23:15:00',
#                '2024-04-01 23:20:00', '2024-04-01 23:25:00',
#                '2024-04-01 23:30:00', '2024-04-01 23:35:00',
#                '2024-04-01 23:40:00', '2024-04-01 23:45:00',
#                '2024-04-01 23:50:00', '2024-04-01 23:55:00'],
#               dtype='datetime64[ns]', name='datetime', length=26028, freq=None)
# Most common time interval: 5 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p03
# 	 old index length: 26028,
# 	 new index length: 26423
#
# ========================
#  Processing patient p04 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p04 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:05:00
# 2025-08-20T18:40:50 - ==============================
# 2025-08-20T18:40:50 - Preprocessing patient p04
# 2025-08-20T18:40:50 - ==============================
#
# 2025-08-20T18:40:50 - Deriving features...
# 2025-08-20T18:40:50 - Filling in gaps...
# 2025-08-20T18:40:50 - Creating COB and carb availability columns...
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-03-27 00:00:00
# 	 Result start time: 06:05:00
# 	 Result end time: 23:55:00
# 	 Result VERY End (last 5):
# 24681   2024-03-27
# 24682   2024-03-27
# 24683   2024-03-27
# 24684   2024-03-27
# 24685   2024-03-27
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p04 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:05:00
# Length of dates: 24686
# Length of times: 24686
# Post-ensure_datetime_index():
# 	Patient p04
# 	index: DatetimeIndex(['2024-01-01 06:05:00', '2024-01-01 06:10:00',
#                '2024-01-01 06:15:00', '2024-01-01 06:20:00',
#                '2024-01-01 06:25:00', '2024-01-01 06:30:00',
#                '2024-01-01 06:35:00', '2024-01-01 06:40:00',
#                '2024-01-01 06:45:00', '2024-01-01 06:50:00',
#                ...
#                '2024-03-27 23:10:00', '2024-03-27 23:15:00',
#                '2024-03-27 23:20:00', '2024-03-27 23:25:00',
#                '2024-03-27 23:30:00', '2024-03-27 23:35:00',
#                '2024-03-27 23:40:00', '2024-03-27 23:45:00',
#                '2024-03-27 23:50:00', '2024-03-27 23:55:00'],
#               dtype='datetime64[ns]', name='datetime', length=24686, freq=None)
# Most common time interval: 5 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p04
# 	 old index length: 24686,
# 	 new index length: 24983
# 2025-08-20T18:40:50 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:50 - Done deriving features.
#
# 2025-08-20T18:40:50 - ==============================
# 2025-08-20T18:40:50 - Preprocessing patient p05
# 2025-08-20T18:40:50 - ==============================
#
# 2025-08-20T18:40:50 - Deriving features...
# 2025-08-20T18:40:50 - Filling in gaps...
# 2025-08-20T18:40:50 - Creating COB and carb availability columns...
# 2025-08-20T18:40:50 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# ========================
#  Processing patient p05 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p05 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:05:00
#
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-04-01 00:00:00
# 	 Result start time: 06:05:00
# 	 Result end time: 23:50:00
# 	 Result VERY End (last 5):
# 8283   2024-04-01
# 8284   2024-04-01
# 8285   2024-04-01
# 8286   2024-04-01
# 8287   2024-04-01
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p05 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:05:00
# Length of dates: 8288
# Length of times: 8288
# Post-ensure_datetime_index():
# 	Patient p05
# 	index: DatetimeIndex(['2024-01-01 06:05:00', '2024-01-01 06:20:00',
#                '2024-01-01 06:35:00', '2024-01-01 06:50:00',
#                '2024-01-01 07:05:00', '2024-01-01 07:20:00',
#                '2024-01-01 07:35:00', '2024-01-01 07:50:00',
#                '2024-01-01 08:05:00', '2024-01-01 08:20:00',
#                ...
#                '2024-04-01 21:30:00', '2024-04-01 21:45:00',
#                '2024-04-01 22:00:00', '2024-04-01 22:20:00',
#                '2024-04-01 22:35:00', '2024-04-01 22:50:00',
#                '2024-04-01 23:05:00', '2024-04-01 23:20:00',
#                '2024-04-01 23:35:00', '2024-04-01 23:50:00'],
#               dtype='datetime64[ns]', name='datetime', length=8288, freq=None)
# Most common time interval: 15 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p05
# 	 old index length: 8288,
# 	 new index length: 8808
# 2025-08-20T18:40:50 - Done deriving features.
#
# 2025-08-20T18:40:51 - ==============================
# 2025-08-20T18:40:51 - Preprocessing patient p06
# 2025-08-20T18:40:51 - ==============================
#
# 2025-08-20T18:40:51 - Deriving features...
# 2025-08-20T18:40:51 - Filling in gaps...
# 2025-08-20T18:40:51 - Creating COB and carb availability columns...
# 2025-08-20T18:40:51 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:51 - Done deriving features.
# ========================
#  Processing patient p06 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p06 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 10:25:00
#
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-04-01 00:00:00
# 	 Result start time: 10:25:00
# 	 Result end time: 23:55:00
# 	 Result VERY End (last 5):
# 8378   2024-04-01
# 8379   2024-04-01
# 8380   2024-04-01
# 8381   2024-04-01
# 8382   2024-04-01
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p06 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 10:25:00
# Length of dates: 8383
# Length of times: 8383
# Post-ensure_datetime_index():
# 	Patient p06
# 	index: DatetimeIndex(['2024-01-01 10:25:00', '2024-01-01 10:40:00',
#                '2024-01-01 10:55:00', '2024-01-01 11:10:00',
#                '2024-01-01 11:25:00', '2024-01-01 11:40:00',
#                '2024-01-01 11:55:00', '2024-01-01 12:10:00',
#                '2024-01-01 12:25:00', '2024-01-01 12:40:00',
#                ...
#                '2024-04-01 19:10:00', '2024-04-01 19:25:00',
#                '2024-04-01 19:40:00', '2024-04-01 19:55:00',
#                '2024-04-01 20:10:00', '2024-04-01 20:25:00',
#                '2024-04-01 20:40:00', '2024-04-01 20:55:00',
#                '2024-04-01 23:40:00', '2024-04-01 23:55:00'],
#               dtype='datetime64[ns]', name='datetime', length=8383, freq=None)
# Most common time interval: 15 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p06
# 	 old index length: 8383,
# 	 new index length: 8791
#
# ========================
#  Processing patient p10 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p10 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:05:00
# 2025-08-20T18:40:51 - ==============================
# 2025-08-20T18:40:51 - Preprocessing patient p10
# 2025-08-20T18:40:51 - ==============================
#
# 2025-08-20T18:40:51 - Deriving features...
# 2025-08-20T18:40:51 - Filling in gaps...
# 2025-08-20T18:40:51 - Creating COB and carb availability columns...
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-03-30 00:00:00
# 	 Result start time: 06:05:00
# 	 Result end time: 20:15:00
# 	 Result VERY End (last 5):
# 25449   2024-03-30
# 25450   2024-03-30
# 25451   2024-03-30
# 25452   2024-03-30
# 25453   2024-03-30
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p10 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:05:00
# Length of dates: 25454
# Length of times: 25454
# Post-ensure_datetime_index():
# 	Patient p10
# 	index: DatetimeIndex(['2024-01-01 06:05:00', '2024-01-01 06:10:00',
#                '2024-01-01 06:15:00', '2024-01-01 06:20:00',
#                '2024-01-01 06:25:00', '2024-01-01 06:30:00',
#                '2024-01-01 06:35:00', '2024-01-01 06:40:00',
#                '2024-01-01 06:45:00', '2024-01-01 06:50:00',
#                ...
#                '2024-03-30 19:30:00', '2024-03-30 19:35:00',
#                '2024-03-30 19:40:00', '2024-03-30 19:45:00',
#                '2024-03-30 19:50:00', '2024-03-30 19:55:00',
#                '2024-03-30 20:00:00', '2024-03-30 20:05:00',
#                '2024-03-30 20:10:00', '2024-03-30 20:15:00'],
#               dtype='datetime64[ns]', name='datetime', length=25454, freq=None)
# Most common time interval: 5 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p10
# 	 old index length: 25454,
# 	 new index length: 25803
# 2025-08-20T18:40:51 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:51 - Done deriving features.
# ========================
#  Processing patient p11 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p11 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 06:05:00
#
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-03-29 00:00:00
# 	 Result start time: 06:05:00
# 	 Result end time: 23:55:00
# 	 Result VERY End (last 5):
# 24550   2024-03-29
# 24551   2024-03-29
# 24552   2024-03-29
# 24553   2024-03-29
# 24554   2024-03-29
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p11 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 06:05:00
# Length of dates: 24555
# Length of times: 24555
# 2025-08-20T18:40:51 - ==============================
# 2025-08-20T18:40:51 - Preprocessing patient p11
# 2025-08-20T18:40:51 - ==============================
#
# 2025-08-20T18:40:51 - Deriving features...
# 2025-08-20T18:40:51 - Filling in gaps...
# 2025-08-20T18:40:51 - Creating COB and carb availability columns...
# 2025-08-20T18:40:51 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# 2025-08-20T18:40:51 - Done deriving features.
# Post-ensure_datetime_index():
# 	Patient p11
# 	index: DatetimeIndex(['2024-01-01 06:05:00', '2024-01-01 06:10:00',
#                '2024-01-01 06:15:00', '2024-01-01 06:20:00',
#                '2024-01-01 06:25:00', '2024-01-01 06:30:00',
#                '2024-01-01 06:35:00', '2024-01-01 06:40:00',
#                '2024-01-01 06:45:00', '2024-01-01 06:50:00',
#                ...
#                '2024-03-29 23:10:00', '2024-03-29 23:15:00',
#                '2024-03-29 23:20:00', '2024-03-29 23:25:00',
#                '2024-03-29 23:30:00', '2024-03-29 23:35:00',
#                '2024-03-29 23:40:00', '2024-03-29 23:45:00',
#                '2024-03-29 23:50:00', '2024-03-29 23:55:00'],
#               dtype='datetime64[ns]', name='datetime', length=24555, freq=None)
# Most common time interval: 5 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p11
# 	 old index length: 24555,
# 	 new index length: 25559
#
# ========================
#  Processing patient p12 data...
# ========================
#
# Running process_patient_data_standalone(),
#  Processing patient p12 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Inputed patient start time: 10:25:00
# 2025-08-20T18:40:52 - ==============================
# 2025-08-20T18:40:52 - Preprocessing patient p12
# 2025-08-20T18:40:52 - ==============================
# 	 Result start date: 2024-01-01 00:00:00
# 	 Result end date: 2024-04-01 00:00:00
# 	 Result start time: 10:25:00
# 	 Result end time: 23:55:00
# 	 Result VERY End (last 5):
# 25294   2024-04-01
# 25295   2024-04-01
# 25296   2024-04-01
# 25297   2024-04-01
# 25298   2024-04-01
# dtype: datetime64[ns]
# 	 Any NaT values in dates? 0
# 	 Any NaT values in times? 0
#
#  Created columns for patient p12 data...
#  	 patient start date: 2024-01-01 00:00:00
# 	 Result patient start time: 10:25:00
# Length of dates: 25299
# Length of times: 25299
# 2025-08-20T18:40:52 - Deriving features...
# 2025-08-20T18:40:52 - Filling in gaps...
# 2025-08-20T18:40:52 - Creating COB and carb availability columns...
# 2025-08-20T18:40:52 - Creating IOB and insulin availability columns. This may take a while depending on the size of the data.
# Post-ensure_datetime_index():
# 	Patient p12
# 	index: DatetimeIndex(['2024-01-01 10:25:00', '2024-01-01 10:30:00',
#                '2024-01-01 10:35:00', '2024-01-01 10:40:00',
#                '2024-01-01 10:45:00', '2024-01-01 10:50:00',
#                '2024-01-01 11:10:00', '2024-01-01 11:15:00',
#                '2024-01-01 11:20:00', '2024-01-01 11:25:00',
#                ...
#                '2024-04-01 23:10:00', '2024-04-01 23:15:00',
#                '2024-04-01 23:20:00', '2024-04-01 23:25:00',
#                '2024-04-01 23:30:00', '2024-04-01 23:35:00',
#                '2024-04-01 23:40:00', '2024-04-01 23:45:00',
#                '2024-04-01 23:50:00', '2024-04-01 23:55:00'],
#               dtype='datetime64[ns]', name='datetime', length=25299, freq=None)
# Most common time interval: 5 minutes
# Post-ensure_regular_time_intervals():
# 	Patient p12
# 	 old index length: 25299,
# 	 new index length: 26371
# 2025-08-20T18:40:52 - Done deriving features.
#
# 2025-08-20T18:40:52 - Done processing train data. Saving processed data to cache...
# 2025-08-20T18:40:52 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:52 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:52 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Saved processed train data for kaggle_brisT1D
# 2025-08-20T18:40:53 - Successfully processed and cached data for 9 patients

# %% [markdown]
# ### New Ensure Regular Time Intervals

# %%
import pandas as pd
from src.data.preprocessing.time_processing import get_most_common_time_interval


def ensure_regular_time_intervals_mapping(df: pd.DataFrame) -> pd.DataFrame:
    """Ensures regular time intervals exist in the dataframe by adding rows with NaN values
    where timestamps are missing, and maps shifted timestamps to the nearest regular interval.

    Args:
        df (pd.DataFrame): Input dataframe with datetime index

    Returns:
        pd.DataFrame: DataFrame with regular time intervals, missing times filled with NaN,
                     and shifted data mapped to nearest regular intervals
    """
    # Validate inputs
    if df.empty:
        return df.copy()  # Return empty DataFrame with same structure

    if df.shape[0] <= 1:
        raise ValueError("DataFrame must contain more than 1 row")

    if "p_num" not in df.columns:
        raise ValueError("DataFrame must contain 'p_num' column")

    if not isinstance(df.index, pd.DatetimeIndex):
        raise ValueError("DataFrame must have datetime index")

    result_df = df.copy()
    freq = get_most_common_time_interval(df)
    print(f"Most common time interval: {freq} minutes")

    # Create complete time range for this patient
    full_time_range = pd.date_range(
        start=df.index.min(),
        end=df.index.max(),
        freq=f"{freq}min",
    )

    # Create a DataFrame with the complete time range
    full_df = pd.DataFrame(index=full_time_range)
    full_df.index.name = "datetime"

    # For each data point, find the nearest regular timestamp
    tolerance = pd.Timedelta(
        minutes=freq * (2 / 3)
    )  # Allow up to two-thirds of the interval as tolerance

    # Use merge_asof to match each original timestamp to the nearest regular timestamp
    # First, prepare the data
    original_data = result_df.reset_index()
    regular_times = pd.DataFrame({"datetime": full_time_range})

    # Sort both dataframes by datetime
    original_data = original_data.sort_values("datetime")
    regular_times = regular_times.sort_values("datetime")

    # Use merge_asof with tolerance to map shifted timestamps to regular intervals
    mapped_data = pd.merge_asof(
        regular_times,
        original_data,
        on="datetime",
        tolerance=tolerance,
        direction="forward",
    )

    # Set datetime back as index
    mapped_data = mapped_data.set_index("datetime")

    # For any regular timestamps that didn't get matched, we'll have NaN values
    # This preserves the regular time grid while capturing shifted data

    print(
        f"Post-ensure_regular_time_intervals(): \n\tPatient {df['p_num'].iloc[0]} \n\t old index length: {len(df.index)}, \n\t new index length: {len(mapped_data.index)}"
    )

    return mapped_data

# %%
datetime_list = [
    "2024-01-01 00:00:00",
    "2024-01-01 00:15:00",
    # Shifted 00:30:00 to 00:40:00
    "2024-01-01 00:40:00",
    "2024-01-01 00:55:00",
    # Missing 00:55:00 to 04:55:00
    "2024-01-01 04:30:00",
    "2024-01-01 04:40:00",
    "2024-01-01 04:55:00",
    "2024-01-01 05:10:00",
]

datetime_index = pd.to_datetime(datetime_list)

data = {
    "p_num": ["patient_01"] * 8,
    "bg_mM": [5.0, 5.2, 5.1, 4.9, 4.1, 4.5, 5.3, 5.0],
    "hr_bpm": [70, 72, 71, 69, 73, 80, 85, 70],
}

df = pd.DataFrame(data, index=datetime_index)
df.index.name = "datetime"
ensure_regular_time_intervals_mapping(df)
# Out:
# Most common time interval: 15 minutes
# Post-ensure_regular_time_intervals():
# 	Patient patient_01
# 	 old index length: 8,
# 	 new index length: 21
#                           p_num  bg_mM  hr_bpm
# datetime
# 2024-01-01 00:00:00  patient_01    5.0    70.0
# 2024-01-01 00:15:00  patient_01    5.2    72.0
# 2024-01-01 00:30:00  patient_01    5.1    71.0
# 2024-01-01 00:45:00  patient_01    4.9    69.0
# 2024-01-01 01:00:00         NaN    NaN     NaN
# 2024-01-01 01:15:00         NaN    NaN     NaN
# 2024-01-01 01:30:00         NaN    NaN     NaN
# 2024-01-01 01:45:00         NaN    NaN     NaN
# 2024-01-01 02:00:00         NaN    NaN     NaN
# 2024-01-01 02:15:00         NaN    NaN     NaN
# 2024-01-01 02:30:00         NaN    NaN     NaN
# 2024-01-01 02:45:00         NaN    NaN     NaN
# 2024-01-01 03:00:00         NaN    NaN     NaN
# 2024-01-01 03:15:00         NaN    NaN     NaN
# 2024-01-01 03:30:00         NaN    NaN     NaN
# 2024-01-01 03:45:00         NaN    NaN     NaN
# 2024-01-01 04:00:00         NaN    NaN     NaN
# 2024-01-01 04:15:00         NaN    NaN     NaN
# 2024-01-01 04:30:00  patient_01    4.1    73.0
# 2024-01-01 04:45:00  patient_01    5.3    85.0
# 2024-01-01 05:00:00  patient_01    5.0    70.0

# %%
import pandas as pd
from src.data.diabetes_datasets.kaggle_bris_t1d.bris_t1d import (
    process_patient_data_standalone,
)


def load_and_process_files_from_path(
    file_path: str,
    generic_patient_start_date: pd.Timestamp = pd.Timestamp("2024-01-01"),
):
    """
    Load all CSV files from a specified path and process them using process_patient_data_standalone.

    Args:
        file_path (str): Path to directory containing patient data files
        generic_patient_start_date (pd.Timestamp): Start date for datetime processing

    Returns:
        dict: Dictionary mapping patient numbers to processed data
    """
    import os

    results = {}

    # Get all CSV files in the directory
    for filename in os.listdir(file_path):
        if filename.endswith(".csv"):
            print(f"\n Processing {filename}")
            file_full_path = os.path.join(file_path, filename)

            # Extract patient number from filename (adjust as needed)
            p_num = filename.replace(".csv", "").replace("patient_", "").split("_")[0]

            # Load the data
            data = pd.read_csv(file_full_path)

            # Process the data
            patient_id, processed_data = process_patient_data_standalone(
                (p_num, data, generic_patient_start_date)
            )
            results[patient_id] = processed_data

            print(f"Processed {filename} for patient {patient_id}")

    return results

# %%
from src.data.cache_manager import get_cache_manager

cache_manager = get_cache_manager()
path = cache_manager.get_cleaning_step_data_path("kaggle_brisT1D")
print(f"{path}")
load_and_process_files_from_path(path)

# %%
import pandas as pd


def count_days_by_max_frequency(datetime_series: pd.Series) -> int:
    """
    Count the number of days based on the maximum frequency that a timestamp occurs.

    This function determines how many unique days are represented in the datetime series
    by finding the most frequent time occurrence and using that to estimate the sampling
    frequency, then calculating the total days covered.

    Args:
        datetime_series (pd.Series): Series of datetime objects

    Returns:
        int: Number of days based on maximum frequency analysis

    Example:
        If you have data every 15 minutes for 3 days, the most frequent interval
        will be 15 minutes, giving you 96 samples per day, so 288 total samples
        would indicate 3 days.
    """
    if len(datetime_series) == 0:
        return 0

    # Convert to datetime if not already
    dt_series = pd.to_datetime(datetime_series)

    # Remove any NaT values and sort
    dt_series = dt_series.dropna().sort_values()

    if len(dt_series) <= 1:
        return 1 if len(dt_series) == 1 else 0

    # Calculate time differences between consecutive timestamps
    time_diffs = dt_series.diff().dropna()

    # Find the most frequent time difference (mode)
    most_frequent_interval = time_diffs.mode()

    if len(most_frequent_interval) == 0:
        # Fallback: use median interval
        interval = time_diffs.median()
    else:
        interval = most_frequent_interval.iloc[0]

    # Convert interval to minutes
    interval_minutes = interval.total_seconds() / 60

    # Calculate samples per day based on the most frequent interval
    samples_per_day = (24 * 60) / interval_minutes

    # Calculate total days based on number of samples
    total_days = len(dt_series) / samples_per_day

    # Round to nearest integer (in case of slight variations)
    return max(1, round(total_days))

# %%
from src.data.cache_manager import get_cache_manager
import os

cache_manager = get_cache_manager()
path = cache_manager.get_cleaning_step_data_path("kaggle_brisT1D")
# Get all CSV files in the directory
for filename in os.listdir(path):
    if filename.endswith(".csv"):
        print(f"\n Processing {filename}")
        file_full_path = os.path.join(path, filename)

        # Extract patient number from filename (adjust as needed)
        p_num = filename.replace(".csv", "").replace("patient_", "").split("_")[0]

        # Load the data
        data = pd.read_csv(file_full_path)

        print(count_days_by_max_frequency(data["datetime"]))
# Out:
#  Processing patient_p02_pre_parallel.csv
# /tmp/ipykernel_3838511/680186738.py:27: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dt_series = pd.to_datetime(datetime_series)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 18
#      15 # Load the data
#      16 data = pd.read_csv(file_full_path)
# ---> 18 print(count_days_by_max_frequency(data['datetime']))
#
# Cell In[6], line 51, in count_days_by_max_frequency(datetime_series)
#      48 interval_minutes = interval.total_seconds() / 60
#      50 # Calculate samples per day based on the most frequent interval
# ---> 51 samples_per_day = (24 * 60) / interval_minutes
#      53 # Calculate total days based on number of samples
#      54 total_days = len(dt_series) / samples_per_day
#
# ZeroDivisionError: float division by zero

# %%
import pandas as pd

raw_data = pd.read_csv("/u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/raw/train.csv")
raw_data.head()
# Out:
# /tmp/ipykernel_223511/3323965087.py:3: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv("/u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/raw/train.csv")
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:00  bg+1:00
# 0            NaN     13.4
# 1            NaN     12.8
# 2            NaN     15.5
# 3            NaN     14.8
# 4            NaN     12.7
#
# [5 rows x 508 columns]

# %%
keep_columns = raw_data.columns
for col in keep_columns:
    print(col)
# Out:
# id
# p_num
# time
# bg-5:55
# bg-5:50
# bg-5:45
# bg-5:40
# bg-5:35
# bg-5:30
# bg-5:25
# bg-5:20
# bg-5:15
# bg-5:10
# bg-5:05
# bg-5:00
# bg-4:55
# bg-4:50
# bg-4:45
# bg-4:40
# bg-4:35
# bg-4:30
# bg-4:25
# bg-4:20
# bg-4:15
# bg-4:10
# bg-4:05
# bg-4:00
# bg-3:55
# bg-3:50
# bg-3:45
# bg-3:40
# bg-3:35
# bg-3:30
# bg-3:25
# bg-3:20
# bg-3:15
# bg-3:10
# bg-3:05
# bg-3:00
# bg-2:55
# bg-2:50
# bg-2:45
# bg-2:40
# bg-2:35
# bg-2:30
# bg-2:25
# bg-2:20
# bg-2:15
# bg-2:10
# bg-2:05
# bg-2:00
# bg-1:55
# bg-1:50
# bg-1:45
# bg-1:40
# bg-1:35
# bg-1:30
# bg-1:25
# bg-1:20
# bg-1:15
# bg-1:10
# bg-1:05
# bg-1:00
# bg-0:55
# bg-0:50
# bg-0:45
# bg-0:40
# bg-0:35
# bg-0:30
# bg-0:25
# bg-0:20
# bg-0:15
# bg-0:10
# bg-0:05
# bg-0:00
# insulin-5:55
# insulin-5:50
# insulin-5:45
# insulin-5:40
# insulin-5:35
# insulin-5:30
# insulin-5:25
# insulin-5:20
# insulin-5:15
# insulin-5:10
# insulin-5:05
# insulin-5:00
# insulin-4:55
# insulin-4:50
# insulin-4:45
# insulin-4:40
# insulin-4:35
# insulin-4:30
# insulin-4:25
# insulin-4:20
# insulin-4:15
# insulin-4:10
# insulin-4:05
# insulin-4:00
# insulin-3:55
# insulin-3:50
# insulin-3:45
# insulin-3:40
# insulin-3:35
# insulin-3:30
# insulin-3:25
# insulin-3:20
# insulin-3:15
# insulin-3:10
# insulin-3:05
# insulin-3:00
# insulin-2:55
# insulin-2:50
# insulin-2:45
# insulin-2:40
# insulin-2:35
# insulin-2:30
# insulin-2:25
# insulin-2:20
# insulin-2:15
# insulin-2:10
# insulin-2:05
# insulin-2:00
# insulin-1:55
# insulin-1:50
# insulin-1:45
# insulin-1:40
# insulin-1:35
# insulin-1:30
# insulin-1:25
# insulin-1:20
# insulin-1:15
# insulin-1:10
# insulin-1:05
# insulin-1:00
# insulin-0:55
# insulin-0:50
# insulin-0:45
# insulin-0:40
# insulin-0:35
# insulin-0:30
# insulin-0:25
# insulin-0:20
# insulin-0:15
# insulin-0:10
# insulin-0:05
# insulin-0:00
# carbs-5:55
# carbs-5:50
# carbs-5:45
# carbs-5:40
# carbs-5:35
# carbs-5:30
# carbs-5:25
# carbs-5:20
# carbs-5:15
# carbs-5:10
# carbs-5:05
# carbs-5:00
# carbs-4:55
# carbs-4:50
# carbs-4:45
# carbs-4:40
# carbs-4:35
# carbs-4:30
# carbs-4:25
# carbs-4:20
# carbs-4:15
# carbs-4:10
# carbs-4:05
# carbs-4:00
# carbs-3:55
# carbs-3:50
# carbs-3:45
# carbs-3:40
# carbs-3:35
# carbs-3:30
# carbs-3:25
# carbs-3:20
# carbs-3:15
# carbs-3:10
# carbs-3:05
# carbs-3:00
# carbs-2:55
# carbs-2:50
# carbs-2:45
# carbs-2:40
# carbs-2:35
# carbs-2:30
# carbs-2:25
# carbs-2:20
# carbs-2:15
# carbs-2:10
# carbs-2:05
# carbs-2:00
# carbs-1:55
# carbs-1:50
# carbs-1:45
# carbs-1:40
# carbs-1:35
# carbs-1:30
# carbs-1:25
# carbs-1:20
# carbs-1:15
# carbs-1:10
# carbs-1:05
# carbs-1:00
# carbs-0:55
# carbs-0:50
# carbs-0:45
# carbs-0:40
# carbs-0:35
# carbs-0:30
# carbs-0:25
# carbs-0:20
# carbs-0:15
# carbs-0:10
# carbs-0:05
# carbs-0:00
# hr-5:55
# hr-5:50
# hr-5:45
# hr-5:40
# hr-5:35
# hr-5:30
# hr-5:25
# hr-5:20
# hr-5:15
# hr-5:10
# hr-5:05
# hr-5:00
# hr-4:55
# hr-4:50
# hr-4:45
# hr-4:40
# hr-4:35
# hr-4:30
# hr-4:25
# hr-4:20
# hr-4:15
# hr-4:10
# hr-4:05
# hr-4:00
# hr-3:55
# hr-3:50
# hr-3:45
# hr-3:40
# hr-3:35
# hr-3:30
# hr-3:25
# hr-3:20
# hr-3:15
# hr-3:10
# hr-3:05
# hr-3:00
# hr-2:55
# hr-2:50
# hr-2:45
# hr-2:40
# hr-2:35
# hr-2:30
# hr-2:25
# hr-2:20
# hr-2:15
# hr-2:10
# hr-2:05
# hr-2:00
# hr-1:55
# hr-1:50
# hr-1:45
# hr-1:40
# hr-1:35
# hr-1:30
# hr-1:25
# hr-1:20
# hr-1:15
# hr-1:10
# hr-1:05
# hr-1:00
# hr-0:55
# hr-0:50
# hr-0:45
# hr-0:40
# hr-0:35
# hr-0:30
# hr-0:25
# hr-0:20
# hr-0:15
# hr-0:10
# hr-0:05
# hr-0:00
# steps-5:55
# steps-5:50
# steps-5:45
# steps-5:40
# steps-5:35
# steps-5:30
# steps-5:25
# steps-5:20
# steps-5:15
# steps-5:10
# steps-5:05
# steps-5:00
# steps-4:55
# steps-4:50
# steps-4:45
# steps-4:40
# steps-4:35
# steps-4:30
# steps-4:25
# steps-4:20
# steps-4:15
# steps-4:10
# steps-4:05
# steps-4:00
# steps-3:55
# steps-3:50
# steps-3:45
# steps-3:40
# steps-3:35
# steps-3:30
# steps-3:25
# steps-3:20
# steps-3:15
# steps-3:10
# steps-3:05
# steps-3:00
# steps-2:55
# steps-2:50
# steps-2:45
# steps-2:40
# steps-2:35
# steps-2:30
# steps-2:25
# steps-2:20
# steps-2:15
# steps-2:10
# steps-2:05
# steps-2:00
# steps-1:55
# steps-1:50
# steps-1:45
# steps-1:40
# steps-1:35
# steps-1:30
# steps-1:25
# steps-1:20
# steps-1:15
# steps-1:10
# steps-1:05
# steps-1:00
# steps-0:55
# steps-0:50
# steps-0:45
# steps-0:40
# steps-0:35
# steps-0:30
# steps-0:25
# steps-0:20
# steps-0:15
# steps-0:10
# steps-0:05
# steps-0:00
# cals-5:55
# cals-5:50
# cals-5:45
# cals-5:40
# cals-5:35
# cals-5:30
# cals-5:25
# cals-5:20
# cals-5:15
# cals-5:10
# cals-5:05
# cals-5:00
# cals-4:55
# cals-4:50
# cals-4:45
# cals-4:40
# cals-4:35
# cals-4:30
# cals-4:25
# cals-4:20
# cals-4:15
# cals-4:10
# cals-4:05
# cals-4:00
# cals-3:55
# cals-3:50
# cals-3:45
# cals-3:40
# cals-3:35
# cals-3:30
# cals-3:25
# cals-3:20
# cals-3:15
# cals-3:10
# cals-3:05
# cals-3:00
# cals-2:55
# cals-2:50
# cals-2:45
# cals-2:40
# cals-2:35
# cals-2:30
# cals-2:25
# cals-2:20
# cals-2:15
# cals-2:10
# cals-2:05
# cals-2:00
# cals-1:55
# cals-1:50
# cals-1:45
# cals-1:40
# cals-1:35
# cals-1:30
# cals-1:25
# cals-1:20
# cals-1:15
# cals-1:10
# cals-1:05
# cals-1:00
# cals-0:55
# cals-0:50
# cals-0:45
# cals-0:40
# cals-0:35
# cals-0:30
# cals-0:25
# cals-0:20
# cals-0:15
# cals-0:10
# cals-0:05
# cals-0:00
# activity-5:55
# activity-5:50
# activity-5:45
# activity-5:40
# activity-5:35
# activity-5:30
# activity-5:25
# activity-5:20
# activity-5:15
# activity-5:10
# activity-5:05
# activity-5:00
# activity-4:55
# activity-4:50
# activity-4:45
# activity-4:40
# activity-4:35
# activity-4:30
# activity-4:25
# activity-4:20
# activity-4:15
# activity-4:10
# activity-4:05
# activity-4:00
# activity-3:55
# activity-3:50
# activity-3:45
# activity-3:40
# activity-3:35
# activity-3:30
# activity-3:25
# activity-3:20
# activity-3:15
# activity-3:10
# activity-3:05
# activity-3:00
# activity-2:55
# activity-2:50
# activity-2:45
# activity-2:40
# activity-2:35
# activity-2:30
# activity-2:25
# activity-2:20
# activity-2:15
# activity-2:10
# activity-2:05
# activity-2:00
# activity-1:55
# activity-1:50
# activity-1:45
# activity-1:40
# activity-1:35
# activity-1:30
# activity-1:25
# activity-1:20
# activity-1:15
# activity-1:10
# activity-1:05
# activity-1:00
# activity-0:55
# activity-0:50
# activity-0:45
# activity-0:40
# activity-0:35
# activity-0:30
# activity-0:25
# activity-0:20
# activity-0:15
# activity-0:10
# activity-0:05
# activity-0:00
# bg+1:00

# %%
keep_columns = [
    "id",
    "p_num",
    "time",
    "bg-0:00",
    "insulin-0:00",
    "carbs-0:00",
    "hr-0:00",
    "steps-0:00",
    "cals-0:00",
    "activity-0:00",
]
raw_data = raw_data[keep_columns]

# %%
raw_data.head()
# Out:
#       id p_num      time  bg-0:00  insulin-0:00  carbs-0:00  hr-0:00  \
# 0  p01_0   p01  06:10:00     15.1        0.0417         NaN      NaN
# 1  p01_1   p01  06:25:00     14.4        0.0417         NaN      NaN
# 2  p01_2   p01  06:40:00     13.9        0.0417         NaN      NaN
# 3  p01_3   p01  06:55:00     13.8        0.0417         NaN      NaN
# 4  p01_4   p01  07:10:00     13.4        0.0417         NaN      NaN
#
#    steps-0:00  cals-0:00 activity-0:00
# 0         NaN        NaN           NaN
# 1         NaN        NaN           NaN
# 2         NaN        NaN           NaN
# 3         NaN        NaN           NaN
# 4         NaN        NaN           NaN

# %%
# Fill NaNs with 0s for calculation purposes
data_filled = raw_data.fillna(0)

# Group by patient and calculate summary statistics
patient_stats = data_filled.groupby("p_num").agg(
    {
        "bg-0:00": ["sum", "mean", "count"],
        "insulin-0:00": ["sum", "mean", "count"],
        "carbs-0:00": ["sum", "mean", "count"],
        "hr-0:00": ["sum", "mean", "count"],
        "steps-0:00": ["sum", "mean", "count"],
        "cals-0:00": ["sum", "mean", "count"],
    }
)

# Flatten column names for easier access
patient_stats.columns = ["_".join(col).strip() for col in patient_stats.columns.values]

# Display the results
print("Summary Statistics by Patient:")
print(patient_stats.round(2))

# Optional: Save to a more readable format
patient_summary = patient_stats.copy()
print("\nFirst 5 patients:")
print(patient_summary.head())
# Out:
# Summary Statistics by Patient:
#        bg-0:00_sum  bg-0:00_mean  bg-0:00_count  insulin-0:00_sum  \
# p_num
# p01        68804.7          8.13           8459           1106.15
# p02       240482.4          9.30          25872           4674.17
# p03       222707.2          8.56          26028           7035.17
# p04       190504.6          7.72          24686           3748.14
# p05        61809.6          7.46           8288           1263.79
# p06        70240.2          8.38           8383           1895.73
# p10       161413.0          6.34          25454           2447.10
# p11       229393.8          9.34          24555           2534.82
# p12       197623.3          7.81          25299           9505.99
#
#        insulin-0:00_mean  insulin-0:00_count  carbs-0:00_sum  carbs-0:00_mean  \
# p_num
# p01                 0.13                8459          3646.0             0.43
# p02                 0.18               25872         17548.0             0.68
# p03                 0.27               26028         25142.0             0.97
# p04                 0.15               24686         13482.0             0.55
# p05                 0.15                8288          3633.0             0.44
# p06                 0.23                8383          4646.0             0.55
# p10                 0.10               25454         18194.0             0.71
# p11                 0.10               24555          7224.0             0.29
# p12                 0.38               25299         30518.0             1.21
#
#        carbs-0:00_count  hr-0:00_sum  hr-0:00_mean  hr-0:00_count  \
# p_num
# p01                8459     619593.9         73.25           8459
# p02               25872     466341.5         18.02          25872
# p03               26028    1768758.8         67.96          26028
# p04               24686    1038415.0         42.06          24686
# p05                8288     514240.9         62.05           8288
# p06                8383     491635.7         58.65           8383
# p10               25454    1843183.3         72.41          25454
# p11               24555    1194798.1         48.66          24555
# p12               25299    2050543.1         81.05          25299
#
#        steps-0:00_sum  steps-0:00_mean  steps-0:00_count  cals-0:00_sum  \
# p_num
# p01          448727.0            53.05              8459       75703.57
# p02          549340.0            21.23             25872       35109.36
# p03          328741.0            12.63             26028      207604.50
# p04          424230.0            17.19             24686      141367.47
# p05          133572.0            16.12              8288       43635.98
# p06          331394.0            39.53              8383       91582.59
# p10          821184.0            32.26             25454      209747.46
# p11          560961.0            22.85             24555      197160.08
# p12          748988.0            29.61             25299      326298.34
#
#        cals-0:00_mean  cals-0:00_count
# p_num
# p01              8.95             8459
# p02              1.36            25872
# p03              7.98            26028
# p04              5.73            24686
# p05              5.26             8288
# p06             10.92             8383
# p10              8.24            25454
# p11              8.03            24555
# p12             12.90            25299
#
# First 5 patients:
#        bg-0:00_sum  bg-0:00_mean  bg-0:00_count  insulin-0:00_sum  \
# p_num
# p01        68804.7      8.133905           8459         1106.1508
# p02       240482.4      9.295083          25872         4674.1741
# p03       222707.2      8.556447          26028         7035.1713
# p04       190504.6      7.717111          24686         3748.1387
# p05        61809.6      7.457722           8288         1263.7901
#
#        insulin-0:00_mean  insulin-0:00_count  carbs-0:00_sum  carbs-0:00_mean  \
# p_num
# p01             0.130766                8459          3646.0         0.431020
# p02             0.180665               25872         17548.0         0.678262
# p03             0.270292               26028         25142.0         0.965960
# p04             0.151833               24686         13482.0         0.546140
# p05             0.152484                8288          3633.0         0.438345
#
#        carbs-0:00_count  hr-0:00_sum  hr-0:00_mean  hr-0:00_count  \
# p_num
# p01                8459     619593.9     73.246708           8459
# p02               25872     466341.5     18.024950          25872
# p03               26028    1768758.8     67.956001          26028
# p04               24686    1038415.0     42.064936          24686
# p05                8288     514240.9     62.046441           8288
#
#        steps-0:00_sum  steps-0:00_mean  steps-0:00_count  cals-0:00_sum  \
# p_num
# p01          448727.0        53.047287              8459       75703.57
# p02          549340.0        21.232993             25872       35109.36
# p03          328741.0        12.630283             26028      207604.50
# p04          424230.0        17.185044             24686      141367.47
# p05          133572.0        16.116313              8288       43635.98
#
#        cals-0:00_mean  cals-0:00_count
# p_num
# p01          8.949470             8459
# p02          1.357041            25872
# p03          7.976199            26028
# p04          5.726625            24686
# p05          5.264959             8288

# %%
patient_summary.round(3).to_csv(
    "/u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed/raw_patient_summary.csv",
    index=True,
)

# %%
processed_data_check_df = pd.read_csv(
    "/u6/cjrisi/nocturnal/scripts/notebooks/data_after_cleaning.csv"
)

# %%
processed_data_check_df.head()
# Out:
#       id p_num  datetime  bg_mM  dose_units  food_g  hr_bpm  steps  cals  \
# 0  p01_0   p01  06:10:00   15.1      0.0417     NaN     NaN    NaN   NaN
# 1  p01_1   p01  06:25:00   14.4      0.0417     NaN     NaN    NaN   NaN
# 2  p01_2   p01  06:40:00   13.9      0.0417     NaN     NaN    NaN   NaN
# 3  p01_3   p01  06:55:00   13.8      0.0417     NaN     NaN    NaN   NaN
# 4  p01_4   p01  07:10:00   13.4      0.0417     NaN     NaN    NaN   NaN
#
#   activity msg_type
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
# Fill NaNs with 0s for calculation purposes
data_filled_dc = processed_data_check_df.fillna(0)

# Group by patient and calculate summary statistics
processed_patient_stats = data_filled_dc.groupby("p_num").agg(
    {
        "bg_mM": ["sum", "mean", "count"],
        "dose_units": ["sum", "mean", "count"],
        "food_g": ["sum", "mean", "count"],
        "hr_bpm": ["sum", "mean", "count"],
        "steps": ["sum", "mean", "count"],
        "cals": ["sum", "mean", "count"],
    }
)

processed_patient_stats.round(3).to_csv(
    "/u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed/processed_patient_summary.csv",
    index=True,
)
