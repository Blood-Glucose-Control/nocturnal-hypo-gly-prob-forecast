# %% [markdown]
# # 1.08 Data Loader Example Notebook
#
# ## Purpose
# This notebook is meant to show how different data loaders behave with our package.

# %% [markdown]
# ### Kaggle Bristol T1D
# #### No Cache - Training Data Load

# %%
from src.data.diabetes_datasets.data_loader import get_loader

# %%
loader = get_loader(
    data_source_name="kaggle_brisT1D",
    dataset_type="train",
    keep_columns=[
        "datetime",
        "p_num",
        "bg_mM",
        "hr_bpm",
        "steps",
        "cals",
        "cob",
        "carb_availability",
        "dose_units",
        "iob",
        "insulin_availability",
    ],
    use_cached=False,
    parallel=True,
    max_workers=9,
)
# Out:
# 2025-09-04T23:58:42 - ============================================================
# 2025-09-04T23:58:42 - Beginning data loading process with the following parmeters:
# 2025-09-04T23:58:42 - 	Dataset: kaggle_brisT1D - train
# 2025-09-04T23:58:42 - 	Columns: ['datetime', 'p_num', 'bg_mM', 'hr_bpm', 'steps', 'cals', 'cob', 'carb_availability', 'dose_units', 'iob', 'insulin_availability']
# 2025-09-04T23:58:42 - 	Generic patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:42 - 	Number of validation days: 20
# 2025-09-04T23:58:42 - 	In parallel with up to 9 workers.
#
# 2025-09-04T23:58:42 - Processed cache not found or not used, processing raw data and saving to cache...
# 2025-09-04T23:58:42 - Raw data for kaggle_brisT1D already exists in cache
# 2025-09-04T23:58:51 - _process_raw_train_data: Processing train data. This may take a while...
# 2025-09-04T23:58:52 - Processing 9 patients:
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p01 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	Inputed patient start time: 06:10:00
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p02 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:52 - 	Inputed patient start time: 06:05:00
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p03 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	Inputed patient start time: 06:05:00
# 2025-09-04T23:58:52 - 	create_dt_col() - Result end date: 2024-03-31 00:00:00
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p05 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	create_dt_col() - Result start time: 06:10:00
# 2025-09-04T23:58:52 - 	create_dt_col() - Result end time: 23:50:00
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p04 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	Inputed patient start time: 06:05:00
# 2025-09-04T23:58:52 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:52 - 	Inputed patient start time: 06:05:00
# 2025-09-04T23:58:52 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:52 - 	Created columns for patient p01 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:52 - 	Result patient start time: 06:10:00
# 2025-09-04T23:58:52 - 	Length of dates: 8459
# 2025-09-04T23:58:52 - 	Length of times: 8459
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p06 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	Inputed patient start time: 10:25:00
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p10 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:52 - 	Inputed patient start time: 06:05:00
# 2025-09-04T23:58:52 - Running process_single_patient_data(),
# 			Processing patient p11 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:53 - 	Inputed patient start time: 06:05:00
# 2025-09-04T23:58:52 - ==============================
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - Preprocessing patient p01
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 06:05:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:50:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 06:05:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - Running process_single_patient_data(),
# 			Processing patient p12 data...
# 			Patient start date: 2024-01-01
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Created columns for patient p05 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:55:00
# 2025-09-04T23:58:53 - 	Result patient start time: 06:05:00
# 2025-09-04T23:58:53 - 	Inputed patient start time: 10:25:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - 	Length of dates: 8288
# 2025-09-04T23:58:53 - 	Length of times: 8288
# 2025-09-04T23:58:53 - 	Most common time interval: 15 minutes
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Created columns for patient p02 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 10:25:00
# 2025-09-04T23:58:53 - 	Result patient start time: 06:05:00
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p01
# 			 - old index length: 8459,
# 			 - new index length: 8711
# 2025-09-04T23:58:53 - 	Length of dates: 25872
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:55:00
# 2025-09-04T23:58:53 - 	Length of times: 25872
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	Created columns for patient p06 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Result patient start time: 10:25:00
# 2025-09-04T23:58:53 - 	Length of dates: 8383
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - 	Length of times: 8383
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - Preprocessing patient p05
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-03-27 00:00:00
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 06:05:00
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:55:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 06:05:00
# 2025-09-04T23:58:53 - 	Most common time interval: 15 minutes
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:55:00
# 2025-09-04T23:58:53 - 	Created columns for patient p04 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Result patient start time: 06:05:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - 	Length of dates: 24686
# 2025-09-04T23:58:53 - 	Length of times: 24686
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p05
# 			 - old index length: 8288,
# 			 - new index length: 8808
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-03-30 00:00:00
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Created columns for patient p03 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - Preprocessing patient p06
# 2025-09-04T23:58:53 - 	Result patient start time: 06:05:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 06:05:00
# 2025-09-04T23:58:53 - 	Length of dates: 26028
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 20:15:00
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Length of times: 26028
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-03-29 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Most common time interval: 15 minutes
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 06:05:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end date: 2024-04-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:55:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Result start time: 10:25:00
# 2025-09-04T23:58:53 - 	Created columns for patient p10 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - 	create_dt_col() - Result end time: 23:55:00
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p06
# 			 - old index length: 8383,
# 			 - new index length: 8791
# 2025-09-04T23:58:53 - 	Result patient start time: 06:05:00
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	Created columns for patient p11 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Length of dates: 25454
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in dates? 0
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - 	Result patient start time: 06:05:00
# 2025-09-04T23:58:53 - 	create_dt_col() - Any NaT values in times? 0
# 2025-09-04T23:58:53 - 	Length of dates: 24555
# 2025-09-04T23:58:53 - 	Length of times: 25454
# 2025-09-04T23:58:53 - 	Created columns for patient p12 data...
# 			Patient start date: 2024-01-01 00:00:00
# 2025-09-04T23:58:53 - 	Length of times: 24555
# 2025-09-04T23:58:53 - 	Result patient start time: 10:25:00
# 2025-09-04T23:58:53 - 	Length of dates: 25299
# 2025-09-04T23:58:53 - 	Length of times: 25299
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - Preprocessing patient p04
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Most common time interval: 5 minutes
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p04
# 			 - old index length: 24686,
# 			 - new index length: 24983
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:53 - 	Processing insulin dynamics
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - Preprocessing patient p11
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Most common time interval: 5 minutes
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - Preprocessing patient p02
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p11
# 			 - old index length: 24555,
# 			 - new index length: 25559
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - 	Most common time interval: 5 minutes
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p02
# 			 - old index length: 25872,
# 			 - new index length: 26423
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - Preprocessing patient p03
# 2025-09-04T23:58:53 - 	Processing insulin dynamics
# 2025-09-04T23:58:53 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Processing insulin dynamics
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Most common time interval: 5 minutes
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - Preprocessing patient p12
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p03
# 			 - old index length: 26028,
# 			 - new index length: 26423
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - Preprocessing patient p10
# 2025-09-04T23:58:53 - ==============================
# 2025-09-04T23:58:53 - derive_features(): Deriving features...
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-04T23:58:53 - 	Most common time interval: 5 minutes
# 2025-09-04T23:58:53 - 	Most common time interval: 5 minutes
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p12
# 			 - old index length: 25299,
# 			 - new index length: 26371
# 2025-09-04T23:58:53 - Post-ensure_regular_time_intervals():
# 			Patient p10
# 			 - old index length: 25454,
# 			 - new index length: 25803
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	Creating COB/IOB and availability columns. This may take a while depending on the size of the data.
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Creating COB and carb availability columns...
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:53 - 	Processing glucose dynamics
# 2025-09-04T23:58:54 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:54 - 	Processing insulin dynamics
# 2025-09-04T23:58:55 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:55 - 	Processing insulin dynamics
# 2025-09-04T23:58:55 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:55 - 	Processing insulin dynamics
# 2025-09-04T23:58:55 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:55 - 	Processing insulin dynamics
# 2025-09-04T23:58:56 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:56 - 	Processing insulin dynamics
# 2025-09-04T23:58:57 - 	Creating IOB and insulin availability columns...
# 2025-09-04T23:58:57 - 	Processing insulin dynamics
# 2025-09-04T23:59:22 - 	Done deriving features.
#
# 2025-09-04T23:59:22 - processed_results: Successfully processed patient p01
# 2025-09-04T23:59:24 - 	Done deriving features.
#
# 2025-09-04T23:59:24 - processed_results: Successfully processed patient p05
# 2025-09-04T23:59:25 - 	Done deriving features.
#
# 2025-09-04T23:59:25 - processed_results: Successfully processed patient p06
# 2025-09-04T23:59:44 - 	Done deriving features.
#
# 2025-09-04T23:59:44 - processed_results: Successfully processed patient p12
# 2025-09-04T23:59:49 - 	Done deriving features.
#
# 2025-09-04T23:59:49 - processed_results: Successfully processed patient p11
# 2025-09-05T00:00:01 - 	Done deriving features.
#
# 2025-09-05T00:00:01 - processed_results: Successfully processed patient p10
# 2025-09-05T00:00:02 - 	Done deriving features.
#
# 2025-09-05T00:00:02 - processed_results: Successfully processed patient p04
# 2025-09-05T00:00:02 - 	Done deriving features.
#
# 2025-09-05T00:00:02 - processed_results: Successfully processed patient p02
# 2025-09-05T00:00:03 - 	Done deriving features.
#
# 2025-09-05T00:00:03 - processed_results: Successfully processed patient p03
# 2025-09-05T00:00:03 - Done processing train data. Saving processed data to cache...
# 2025-09-05T00:00:03 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:03 - 	Saved processed train data for kaggle_brisT1D - patient: p01
# 2025-09-05T00:00:03 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p05
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p06
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p12
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p11
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p10
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p04
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p02
# 2025-09-05T00:00:04 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:00:04 - 	Saved processed train data for kaggle_brisT1D - patient: p03
# 2025-09-05T00:00:04 - Successfully processed and cached data for 9 patients

# %%
for key, value in loader.processed_data.items():
    print(f"{key}: {value.shape}")
# Out:
# p01: (8711, 14)
# p05: (8808, 14)
# p06: (8791, 14)
# p12: (26371, 14)
# p11: (25559, 14)
# p10: (25803, 14)
# p04: (24983, 14)
# p02: (26423, 14)
# p03: (26423, 14)

# %% [markdown]
# #### Cached - Training Data Load

# %%
loader = get_loader(
    data_source_name="kaggle_brisT1D",
    dataset_type="train",
    keep_columns=[
        "datetime",
        "p_num",
        "bg_mM",
        "hr_bpm",
        "steps",
        "cals",
        "cob",
        "carb_availability",
        "dose_units",
        "iob",
        "insulin_availability",
    ],
    use_cached=True,
    parallel=True,
    max_workers=9,
)
# Out:
# 2025-09-05T00:01:14 - ============================================================
# 2025-09-05T00:01:14 - Beginning data loading process with the following parmeters:
# 2025-09-05T00:01:14 - 	Dataset: kaggle_brisT1D - train
# 2025-09-05T00:01:14 - 	Columns: ['datetime', 'p_num', 'bg_mM', 'hr_bpm', 'steps', 'cals', 'cob', 'carb_availability', 'dose_units', 'iob', 'insulin_availability']
# 2025-09-05T00:01:14 - 	Generic patient start date: 2024-01-01 00:00:00
# 2025-09-05T00:01:14 - 	Number of validation days: 20
# 2025-09-05T00:01:14 - 	In parallel with up to 9 workers.
#
# 2025-09-05T00:01:14 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:01:14 - cache_manager.load_processed_data() returned:
#  ['p11', 'p10', 'p12', 'p04', 'p05', 'p06', 'p01', 'p02', 'p03']
# 2025-09-05T00:01:14 - Loading processed data from cache...

# %% [markdown]
# #### Processed Training Data

# %%
for p_num, df in loader.train_data.items():
    print(f"Patient Number: {p_num}")
    print(f"DataFrame Shape: {df.shape}")   
    print(f"Dataframe Head:\n{df.head()}\n")
# Out:
# Patient Number: p11
# DataFrame Shape: (18803, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:05:00   p11    9.3     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:10:00   p11    9.2     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:15:00   p11    9.1     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:20:00   p11    9.1     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:25:00   p11    9.2     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units  iob  insulin_availability
# datetime
# 2024-01-01 06:05:00         NaN  0.0                   0.0
# 2024-01-01 06:10:00         NaN  0.0                   0.0
# 2024-01-01 06:15:00         NaN  0.0                   0.0
# 2024-01-01 06:20:00         NaN  0.0                   0.0
# 2024-01-01 06:25:00         NaN  0.0                   0.0
#
# Patient Number: p10
# DataFrame Shape: (19622, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:05:00   p10    5.1     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:10:00   p10    5.4     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:15:00   p10    5.2     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:20:00   p10    5.1     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:25:00   p10    4.9     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units     iob  insulin_availability
# datetime
# 2024-01-01 06:05:00      0.0000  0.0000              0.000000
# 2024-01-01 06:10:00      0.0167  0.0167              0.000000
# 2024-01-01 06:15:00      0.0696  0.0863              0.000000
# 2024-01-01 06:20:00      0.0614  0.1477              0.000000
# 2024-01-01 06:25:00      0.0262  0.1739              0.000138
#
# Patient Number: p12
# DataFrame Shape: (19621, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 10:25:00   p12    4.1    63.9    NaN   NaN  0.0                0.0
# 2024-01-01 10:30:00   p12    4.2    89.3    NaN   NaN  0.0                0.0
# 2024-01-01 10:35:00   p12    4.3   112.6    NaN   NaN  0.0                0.0
# 2024-01-01 10:40:00   p12    4.5   105.5    NaN   NaN  0.0                0.0
# 2024-01-01 10:45:00   p12    4.1   106.0    NaN   NaN  0.0                0.0
#
#                      dose_units  iob  insulin_availability
# datetime
# 2024-01-01 10:25:00         0.0  0.0                   0.0
# 2024-01-01 10:30:00         0.0  0.0                   0.0
# 2024-01-01 10:35:00         0.0  0.0                   0.0
# 2024-01-01 10:40:00         0.0  0.0                   0.0
# 2024-01-01 10:45:00         0.0  0.0                   0.0
#
# Patient Number: p04
# DataFrame Shape: (18777, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:05:00   p04    6.7     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:10:00   p04    6.6     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:15:00   p04    6.2     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:20:00   p04    6.0     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:25:00   p04    5.7     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-01-01 06:05:00      0.0706  0.070600              0.000000
# 2024-01-01 06:10:00      0.0901  0.160700              0.000000
# 2024-01-01 06:15:00      0.0756  0.236300              0.000000
# 2024-01-01 06:20:00      0.0482  0.284500              0.000583
# 2024-01-01 06:25:00      0.0205  0.304597              0.001986
#
# Patient Number: p05
# DataFrame Shape: (6322, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:05:00   p05    3.6     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:20:00   p05    3.7     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:35:00   p05    3.8     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:50:00   p05    3.9     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 07:05:00   p05    4.0     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-01-01 06:05:00      0.0729  0.072900              0.000000
# 2024-01-01 06:20:00      0.0729  0.145800              0.000000
# 2024-01-01 06:35:00      0.0729  0.218700              0.000000
# 2024-01-01 06:50:00      0.0729  0.291600              0.005422
# 2024-01-01 07:05:00      0.0729  0.353276              0.007507
#
# Patient Number: p06
# DataFrame Shape: (6434, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 10:25:00   p06   11.4     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 10:40:00   p06   11.3     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 10:55:00   p06   10.9     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 11:10:00   p06   10.4     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 11:25:00   p06   10.4     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-01-01 10:25:00      0.0833  0.083300              0.000000
# 2024-01-01 10:40:00      0.0833  0.166600              0.000000
# 2024-01-01 10:55:00      0.0833  0.249900              0.000000
# 2024-01-01 11:10:00      0.0833  0.333200              0.006196
# 2024-01-01 11:25:00      0.0833  0.403675              0.008578
#
# Patient Number: p01
# DataFrame Shape: (6499, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:10:00   p01   15.1     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:25:00   p01   14.4     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:40:00   p01   13.9     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:55:00   p01   13.8     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 07:10:00   p01   13.4     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units      iob  insulin_availability
# datetime
# 2024-01-01 06:10:00      0.0417  0.04170              0.000000
# 2024-01-01 06:25:00      0.0417  0.08340              0.000000
# 2024-01-01 06:40:00      0.0417  0.12510              0.000000
# 2024-01-01 06:55:00      0.0417  0.16680              0.003102
# 2024-01-01 07:10:00      0.0417  0.20208              0.004294
#
# Patient Number: p02
# DataFrame Shape: (20211, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:05:00   p02    6.7     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:10:00   p02    6.5     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:15:00   p02    6.5     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:20:00   p02    6.5     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:25:00   p02    6.5     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-01-01 06:05:00      0.0510  0.051000              0.000000
# 2024-01-01 06:10:00      0.0567  0.107700              0.000000
# 2024-01-01 06:15:00      0.0583  0.166000              0.000000
# 2024-01-01 06:20:00      0.0573  0.223300              0.000421
# 2024-01-01 06:25:00      0.0580  0.281009              0.001366
#
# Patient Number: p03
# DataFrame Shape: (20225, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-01-01 06:05:00   p03    7.6     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:10:00   p03    7.3     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:15:00   p03    7.2     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:20:00   p03    7.2     NaN    NaN   NaN  0.0                0.0
# 2024-01-01 06:25:00   p03    7.1     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-01-01 06:05:00      0.0833  0.083300              0.000000
# 2024-01-01 06:10:00      0.1100  0.193300              0.000000
# 2024-01-01 06:15:00      0.1252  0.318500              0.000000
# 2024-01-01 06:20:00      0.1188  0.437300              0.000688
# 2024-01-01 06:25:00      0.1167  0.553525              0.002374

# %% [markdown]
# #### Processed Validation Data

# %%
for p_num, df in loader.validation_data.items():
    print(f"Patient Number: {p_num}")
    print(f"DataFrame Shape: {df.shape}")   
    print(f"Dataframe Head:\n{df.head()}\n")
# Out:
# Patient Number: p11
# DataFrame Shape: (5548, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-09 06:55:00   p11    4.6     NaN    NaN  5.95  0.0                0.0
# 2024-03-09 07:00:00   p11    4.6     NaN    NaN  5.95  0.0                0.0
# 2024-03-09 07:05:00   p11    4.6     NaN    NaN  5.95  0.0                0.0
# 2024-03-09 07:10:00   p11    4.5     NaN    NaN  5.95  0.0                0.0
# 2024-03-09 07:15:00   p11    4.3     NaN    NaN  5.95  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-09 06:55:00       0.075  1.841735              0.104553
# 2024-03-09 07:00:00       0.075  1.831227              0.104047
# 2024-03-09 07:05:00       0.075  1.818093              0.103205
# 2024-03-09 07:10:00       0.075  1.805540              0.102358
# 2024-03-09 07:15:00       0.075  1.793572              0.101515
#
# Patient Number: p10
# DataFrame Shape: (5672, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-10 06:55:00   p10    5.1    60.5    NaN  5.85  0.0                0.0
# 2024-03-10 07:00:00   p10    5.1    60.7    NaN  5.97  0.0                0.0
# 2024-03-10 07:05:00   p10    5.0    62.3    9.0  5.85  0.0                0.0
# 2024-03-10 07:10:00   p10    5.1    57.8    NaN  5.85  0.0                0.0
# 2024-03-10 07:15:00   p10    5.1    57.0    0.0  5.85  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-10 06:55:00      0.0264  0.458768              0.025758
# 2024-03-10 07:00:00      0.0306  0.461152              0.024976
# 2024-03-10 07:05:00      0.0252  0.464182              0.024707
# 2024-03-10 07:10:00      0.0176  0.463326              0.024845
# 2024-03-10 07:15:00      0.0180  0.464184              0.025214
#
# Patient Number: p12
# DataFrame Shape: (5474, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-12 06:55:00   p12    6.6    70.2    NaN  6.75  0.0                0.0
# 2024-03-12 07:00:00   p12    6.4    63.2    NaN  6.75  0.0                0.0
# 2024-03-12 07:05:00   p12    6.2    65.7    NaN  6.75  0.0                0.0
# 2024-03-12 07:10:00   p12    6.0    68.6    NaN  6.75  0.0                0.0
# 2024-03-12 07:15:00   p12    6.1    65.9    NaN  6.75  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-12 06:55:00       0.000  1.941988              0.119506
# 2024-03-12 07:00:00       0.000  1.801611              0.114924
# 2024-03-12 07:05:00       0.000  1.668851              0.110110
# 2024-03-12 07:10:00       0.075  1.609957              0.104180
# 2024-03-12 07:15:00       0.050  1.530156              0.097740
#
# Patient Number: p04
# DataFrame Shape: (5705, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-07 06:55:00   p04    6.2    60.1    0.0  4.64  0.0                0.0
# 2024-03-07 07:00:00   p04    6.3    57.8    NaN  4.55  0.0                0.0
# 2024-03-07 07:05:00   p04    6.5    60.3    NaN  4.55  0.0                0.0
# 2024-03-07 07:10:00   p04    6.7    60.5    NaN  4.55  0.0                0.0
# 2024-03-07 07:15:00   p04    6.8    60.4    0.0  4.55  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-07 06:55:00      0.0702  0.974915              0.043537
# 2024-03-07 07:00:00      0.0499  0.982158              0.043948
# 2024-03-07 07:05:00      0.0682  1.007416              0.044622
# 2024-03-07 07:10:00      0.0708  1.034810              0.045502
# 2024-03-07 07:15:00      0.0708  1.061810              0.046397
#
# Patient Number: p05
# DataFrame Shape: (1893, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-12 06:50:00   p05    7.8     NaN    NaN  4.75  0.0                0.0
# 2024-03-12 07:05:00   p05    7.1     NaN    NaN  4.75  0.0                0.0
# 2024-03-12 07:20:00   p05    6.8     NaN    NaN  4.75  0.0                0.0
# 2024-03-12 07:35:00   p05    7.1     NaN    NaN  4.75  0.0                0.0
# 2024-03-12 07:50:00   p05    7.4     NaN    NaN  4.75  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-12 06:50:00      0.0792  0.639965              0.033517
# 2024-03-12 07:05:00      0.0792  0.639965              0.033517
# 2024-03-12 07:20:00      0.0792  0.639965              0.033517
# 2024-03-12 07:35:00      0.0812  0.641965              0.033517
# 2024-03-12 07:50:00      0.0812  0.643965              0.033517
#
# Patient Number: p06
# DataFrame Shape: (1891, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps   cals   cob  \
# datetime
# 2024-03-12 06:55:00   p06   20.3    57.6    0.0  13.58   0.0
# 2024-03-12 07:10:00   p06   21.7    65.8   58.0  17.90   0.0
# 2024-03-12 07:25:00   p06   22.8    60.5    4.0  16.05   0.0
# 2024-03-12 07:40:00   p06   21.9    60.7   10.0   7.27  24.0
# 2024-03-12 07:55:00   p06   19.9    58.4    0.0   6.28  24.0
#
#                      carb_availability  dose_units       iob  \
# datetime
# 2024-03-12 06:55:00                0.0      0.0833  0.673095
# 2024-03-12 07:10:00                0.0      0.0833  0.673095
# 2024-03-12 07:25:00                0.0      0.0833  0.673095
# 2024-03-12 07:40:00                0.0      4.3333  4.923095
# 2024-03-12 07:55:00                0.0      0.0833  4.923095
#
#                      insulin_availability
# datetime
# 2024-03-12 06:55:00              0.035252
# 2024-03-12 07:10:00              0.035252
# 2024-03-12 07:25:00              0.035252
# 2024-03-12 07:40:00              0.035252
# 2024-03-12 07:55:00              0.035252
#
# Patient Number: p01
# DataFrame Shape: (1887, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps   cals  cob  \
# datetime
# 2024-03-11 07:10:00   p01    NaN    80.3   92.0   4.80  0.0
# 2024-03-11 07:25:00   p01    NaN    75.5    0.0   4.80  0.0
# 2024-03-11 07:40:00   p01    NaN    76.9   65.0   4.80  0.0
# 2024-03-11 07:55:00   p01    NaN    77.1    0.0   5.00  0.0
# 2024-03-11 08:10:00   p01   12.1    82.5  127.0  13.48  0.0
#
#                      carb_availability  dose_units      iob  \
# datetime
# 2024-03-11 07:10:00                0.0      0.0417  0.04170
# 2024-03-11 07:25:00                0.0      0.0417  0.08340
# 2024-03-11 07:40:00                0.0      0.0417  0.12510
# 2024-03-11 07:55:00                0.0      0.0417  0.16680
# 2024-03-11 08:10:00                0.0      0.0583  0.21868
#
#                      insulin_availability
# datetime
# 2024-03-11 07:10:00              0.000000
# 2024-03-11 07:25:00              0.000000
# 2024-03-11 07:40:00              0.000000
# 2024-03-11 07:55:00              0.003102
# 2024-03-11 08:10:00              0.004294
#
# Patient Number: p02
# DataFrame Shape: (5457, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-12 06:55:00   p02    6.9     NaN    NaN   NaN  0.0                0.0
# 2024-03-12 07:00:00   p02    7.2     NaN    NaN   NaN  0.0                0.0
# 2024-03-12 07:05:00   p02    7.4     NaN    NaN   NaN  0.0                0.0
# 2024-03-12 07:10:00   p02    7.3     NaN    NaN   NaN  0.0                0.0
# 2024-03-12 07:15:00   p02    7.4     NaN    NaN   NaN  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-12 06:55:00      0.0583  0.613921              0.016006
# 2024-03-12 07:00:00      0.0583  0.661177              0.018739
# 2024-03-12 07:05:00      0.0583  0.706547              0.021541
# 2024-03-12 07:10:00      0.0583  0.749984              0.024377
# 2024-03-12 07:15:00      0.0583  0.791464              0.027217
#
# Patient Number: p03
# DataFrame Shape: (5599, 10)
# Dataframe Head:
#                     p_num  bg_mM  hr_bpm  steps  cals  cob  carb_availability  \
# datetime
# 2024-03-12 06:55:00   p03    6.3    53.0    NaN   5.6  0.0                0.0
# 2024-03-12 07:00:00   p03    6.3    53.1    NaN   5.6  0.0                0.0
# 2024-03-12 07:05:00   p03    6.3    56.6    0.0   5.6  0.0                0.0
# 2024-03-12 07:10:00   p03    6.3    53.9    NaN   5.6  0.0                0.0
# 2024-03-12 07:15:00   p03    6.3    52.9    NaN   5.6  0.0                0.0
#
#                      dose_units       iob  insulin_availability
# datetime
# 2024-03-12 06:55:00      0.1167  1.983091              0.103674
# 2024-03-12 07:00:00      0.1167  2.014124              0.103788
# 2024-03-12 07:05:00      0.1167  2.044365              0.104133
# 2024-03-12 07:10:00      0.1167  2.074208              0.104747
# 2024-03-12 07:15:00      0.1167  2.103147              0.105553

# %% [markdown]
# #### Testing Data

# %%
from src.data.diabetes_datasets.data_loader import get_loader

loader = get_loader(
    data_source_name="kaggle_brisT1D",
    dataset_type="test",
    keep_columns=[
        "datetime",
        "p_num",
        "bg_mM",
        "hr_bpm",
        "steps",
        "cals",
        "cob",
        "carb_availability",
        "dose_units",
        "iob",
        "insulin_availability",
    ],
    use_cached=False,
    parallel=True,
    max_workers=2,
)
# Out:
# 2025-09-05T00:01:33 - ============================================================
# 2025-09-05T00:01:33 - Beginning data loading process with the following parmeters:
# 2025-09-05T00:01:33 - 	Dataset: kaggle_brisT1D - test
# 2025-09-05T00:01:33 - 	Columns: ['datetime', 'p_num', 'bg_mM', 'hr_bpm', 'steps', 'cals', 'cob', 'carb_availability', 'dose_units', 'iob', 'insulin_availability']
# 2025-09-05T00:01:33 - 	Generic patient start date: 2024-01-01 00:00:00
# 2025-09-05T00:01:33 - 	In parallel with up to 2 workers.
#
# 2025-09-05T00:01:33 - Processed cache not found or not used, processing raw data and saving to cache...
# 2025-09-05T00:01:33 - Raw data for kaggle_brisT1D already exists in cache
# 2025-09-05T00:01:33 - Processing test data. This may take a while...
# 2025-09-05T00:03:00 - Processed data path for kaggle_brisT1D: /u6/cjrisi/nocturnal/cache/data/kaggle_brisT1D/processed
# 2025-09-05T00:03:00 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:00 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:00 - Post-ensure_regular_time_intervals():
# 			Patient p02
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:00 - 	Processing glucose dynamics
# 2025-09-05T00:03:00 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:00 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:00 - Post-ensure_regular_time_intervals():
# 			Patient p01
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:00 - 	Processing glucose dynamics
# 2025-09-05T00:03:01 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:01 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:01 - Post-ensure_regular_time_intervals():
# 			Patient p04
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:01 - 	Processing glucose dynamics
# 2025-09-05T00:03:01 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:01 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:01 - Post-ensure_regular_time_intervals():
# 			Patient p06
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:01 - 	Processing glucose dynamics
# 2025-09-05T00:03:01 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:01 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:01 - Post-ensure_regular_time_intervals():
# 			Patient p05
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:01 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:01 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:01 - 	Processing glucose dynamics
# 2025-09-05T00:03:01 - Post-ensure_regular_time_intervals():
# 			Patient p10
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:01 - 	Processing glucose dynamics
# 2025-09-05T00:03:01 - ensure_regular_time_intervals(): Ensuring regular time intervals...
# 2025-09-05T00:03:01 - 	Most common time interval: 5 minutes
# 2025-09-05T00:03:01 - Post-ensure_regular_time_intervals():
# 			Patient p11
# 			 - old index length: 72,
# 			 - new index length: 72
# 2025-09-05T00:03:01 - 	Processing glucose dynamics
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/u6/cjrisi/nocturnal/.noctprob-venv/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'food_g'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/process.py", line 256, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/process.py", line 205, in _process_chunk
#     return [fn(*args) for args in chunk]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/process.py", line 205, in <listcomp>
#     return [fn(*args) for args in chunk]
#             ^^^^^^^^^
#   File "/u6/cjrisi/nocturnal/src/data/diabetes_datasets/kaggle_bris_t1d/bris_t1d.py", line 761, in _process_patient_test_data
#     row_df.pipe(create_cob_and_carb_availability_cols, freq)
#   File "/u6/cjrisi/nocturnal/.noctprob-venv/lib/python3.11/site-packages/pandas/core/generic.py", line 6231, in pipe
#     return common.pipe(self, func, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/u6/cjrisi/nocturnal/.noctprob-venv/lib/python3.11/site-packages/pandas/core/common.py", line 502, in pipe
#     return func(obj, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/u6/cjrisi/nocturnal/src/data/physiological/carb_model/carb_model.py", line 113, in create_cob_and_carb_availability_cols
#     for meal_time in result_df.index[result_df["food_g"].notna()]:
#                                      ~~~~~~~~~^^^^^^^^^^
#   File "/u6/cjrisi/nocturnal/.noctprob-venv/lib/python3.11/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/u6/cjrisi/nocturnal/.noctprob-venv/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'food_g'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 from src.data.diabetes_datasets.data_loader import get_loader
# ----> 3 loader = get_loader(
#       4     data_source_name="kaggle_brisT1D",
#       5     dataset_type="test",
#       6     keep_columns=[
#       7         "datetime",
#       8         "p_num",
#       9         "bg_mM",
#      10         "hr_bpm",
#      11         "steps",
#      12         "cals",
#      13         "cob",
#      14         "carb_availability",
#      15         "dose_units",
#      16         "iob",
#      17         "insulin_availability",
#      18     ],
#      19     use_cached=False,
#      20     parallel=True,
#      21     max_workers=2,
#      22 )
#
# File ~/nocturnal/src/data/diabetes_datasets/data_loader.py:84, in get_loader(data_source_name, dataset_type, keep_columns, use_cached, num_validation_days, config, parallel, max_workers)
#      57 """
#      58 Factory function to create and return the appropriate data loader instance.
#      59
#    (...)     81     ValueError: If an unsupported data source name is provided.
#      82 """
#      83 if data_source_name == "kaggle_brisT1D":
# ---> 84     return BrisT1DDataLoader(
#      85         keep_columns=keep_columns,
#      86         num_validation_days=num_validation_days,
#      87         use_cached=use_cached,
#      88         dataset_type=dataset_type,
#      89         parallel=parallel,
#      90         max_workers=max_workers,
#      91     )
#      92 elif data_source_name == "gluroo":
#      93     return GlurooDataLoader(
#      94         keep_columns=keep_columns,
#      95         num_validation_days=num_validation_days,
#      96         config=config,
#      97         parallel=parallel,
#      98     )
#
# File ~/nocturnal/src/data/diabetes_datasets/kaggle_bris_t1d/bris_t1d.py:243, in BrisT1DDataLoader.__init__(self, keep_columns, num_validation_days, use_cached, dataset_type, parallel, generic_patient_start_date, max_workers)
#     240 self.num_train_days = None
#     242 # Preload data
# --> 243 self.load_data()
#
# File ~/nocturnal/src/data/diabetes_datasets/kaggle_bris_t1d/bris_t1d.py:313, in BrisT1DDataLoader.load_data(self)
#     309 if need_to_process_data:
#     310     logger.info(
#     311         "Processed cache not found or not used, processing raw data and saving to cache..."
#     312     )
# --> 313     self._process_and_cache_data()
#     315 # Split train/validation data
#     316 if self.dataset_type == "train" and isinstance(
#     317     self.processed_data, dict
#     318 ):
#
# File ~/nocturnal/src/data/diabetes_datasets/kaggle_bris_t1d/bris_t1d.py:427, in BrisT1DDataLoader._process_and_cache_data(self)
#     422 """
#     423 Try to load the raw data, process it and save it to cache.
#     424 If the raw data is not available, fetch it from Kaggle.
#     425 """
#     426 self.raw_data = self.load_raw()
# --> 427 self.processed_data = self._process_raw_data()
#
# File ~/nocturnal/src/data/diabetes_datasets/kaggle_bris_t1d/bris_t1d.py:566, in BrisT1DDataLoader._process_raw_data(self)
#     563     return self._process_raw_train_data()
#     565 elif self.dataset_type == "test":
# --> 566     return self._process_raw_test_data()
#     568 else:
#     569     raise ValueError(
#     570         f"Unknown dataset_type: {self.dataset_type}. Must be 'train' or 'test'."
#     571     )
#
# File ~/nocturnal/src/data/diabetes_datasets/kaggle_bris_t1d/bris_t1d.py:726, in BrisT1DDataLoader._process_raw_test_data(self)
#     723 results = executor.map(process_patient_fn, data.items())
#     725 # Merge results into processed_data
# --> 726 for pid, patient_data in results:
#     727     processed_data[pid] = patient_data
#     729 return processed_data
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/process.py:602, in _chain_from_iterable_of_lists(iterable)
#     596 def _chain_from_iterable_of_lists(iterable):
#     597     """
#     598     Specialized implementation of itertools.chain.from_iterable.
#     599     Each item in *iterable* should be a list.  This function is
#     600     careful not to keep references to yielded objects.
#     601     """
# --> 602     for element in iterable:
#     603         element.reverse()
#     604         while element:
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/anaconda3/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# KeyError: 'food_g'
