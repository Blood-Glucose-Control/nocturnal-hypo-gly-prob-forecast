# %%
# Imports
import pandas as pd
from src.utils.os_helper import get_project_root
from src.data.models import ColumnNames

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
root = get_project_root()
CACHE_DIR = root / "cache" / "data" / "awesome_cgm" / "brown_2019"
data_tables = (
    CACHE_DIR / "raw" / "DCLP3 Public Dataset - Release 3 - 2022-08-04" / "Data Files"
)

# %%
cgm_df = pd.read_csv(data_tables / "cgm.txt", sep="|")

# %%
cgm_df = cgm_df.rename(columns={"Unnamed: 3": "CGM"})

# %%
cgm_df.head()
# Out:
#    PtID       Period          DataDtTm  CGM
# 0     1  1. Baseline  11DEC17:23:59:25  172
# 1     1  1. Baseline  12DEC17:00:04:24  170
# 2     1  1. Baseline  12DEC17:00:09:24  167
# 3     1  1. Baseline  12DEC17:00:14:25  163
# 4     1  1. Baseline  12DEC17:00:19:25  160

# %%
cgm_df.columns
# Out:
# Index(['PtID', 'Period', 'DataDtTm', 'CGM'], dtype='object')

# %%
cgm_df.groupby("PtID")["Period"].value_counts().unstack(fill_value=0)
# Out:
# Period  1. Baseline  2. Post Randomization
# PtID
# 1              4009                  53007
# 2              3667                  49870
# 3              3982                  53617
# 4              3656                  45149
# 5              3614                  53537
# ...             ...                    ...
# 167            3686                  51587
# 168            3655                  52411
# 169            3664                  53891
# 170            2496                  43801
# 171            3382                  51602
#
# [168 rows x 2 columns]

# %%
cgm_df[ColumnNames.DATETIME.value] = pd.to_datetime(
    cgm_df["DataDtTm"], format="%d%b%y:%H:%M:%S"
)

# Set datetime as index
cgm_df = cgm_df.set_index(ColumnNames.DATETIME.value)

cgm_df = cgm_df.drop(columns=["DataDtTm"])

# %%
cgm_df.head()
# Out:
#                      PtID       Period  CGM
# datetime
# 2017-12-11 23:59:25     1  1. Baseline  172
# 2017-12-12 00:04:24     1  1. Baseline  170
# 2017-12-12 00:09:24     1  1. Baseline  167
# 2017-12-12 00:14:25     1  1. Baseline  163
# 2017-12-12 00:19:25     1  1. Baseline  160

# %%
# Rename to match ColumnNames enum
cgm_df = cgm_df.rename(
    columns={
        "PtID": ColumnNames.P_NUM.value,
        "CGM": "bg_mgdL",  # Keep original, add mmol/L version
        "Period": "period",
    }
)

# Add mmol/L version
cgm_df[ColumnNames.BG.value] = cgm_df["bg_mgdL"] / 18.0

# %%
cgm_df.head()
# Out:
#                      p_num       period  bg_mgdL     bg_mM
# datetime
# 2017-12-11 23:59:25      1  1. Baseline      172  9.555556
# 2017-12-12 00:04:24      1  1. Baseline      170  9.444444
# 2017-12-12 00:09:24      1  1. Baseline      167  9.277778
# 2017-12-12 00:14:25      1  1. Baseline      163  9.055556
# 2017-12-12 00:19:25      1  1. Baseline      160  8.888889

# %%
from src.data.preprocessing.data_splitting import split_multipatient_dataframe
from src.data.preprocessing.sampling import (
    ensure_regular_time_intervals_with_aggregation,
)

# Split into per-patient dict first
patient_dict = split_multipatient_dataframe(cgm_df, patient_col="p_num")

# Then process each
for pid, pdf in patient_dict.items():
    processed_df, freq = ensure_regular_time_intervals_with_aggregation(pdf)
    patient_dict[pid] = processed_df
# Out:
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 1
# 			 - old index length: 57016,
# 			 - new index length: 58465
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 10
# 			 - old index length: 55890,
# 			 - new index length: 57313
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 100
# 			 - old index length: 54885,
# 			 - new index length: 55752
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 101
# 			 - old index length: 53112,
# 			 - new index length: 55121
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 102
# 			 - old index length: 56817,
# 			 - new index length: 58464
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 103
# 			 - old index length: 53217,
# 			 - new index length: 56505
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 104
# 			 - old index length: 52310,
# 			 - new index length: 55413
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 105
# 			 - old index length: 50627,
# 			 - new index length: 55008
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 106
# 			 - old index length: 55464,
# 			 - new index length: 56450
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 107
# 			 - old index length: 53082,
# 			 - new index length: 55583
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 108
# 			 - old index length: 55061,
# 			 - new index length: 56245
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 109
# 			 - old index length: 55375,
# 			 - new index length: 56026
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 110
# 			 - old index length: 55371,
# 			 - new index length: 58752
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 111
# 			 - old index length: 56423,
# 			 - new index length: 58289
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 112
# 			 - old index length: 47977,
# 			 - new index length: 55991
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 113
# 			 - old index length: 54832,
# 			 - new index length: 57031
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 114
# 			 - old index length: 51010,
# 			 - new index length: 55391
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 115
# 			 - old index length: 55276,
# 			 - new index length: 58178
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 116
# 			 - old index length: 52358,
# 			 - new index length: 56736
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 117
# 			 - old index length: 56574,
# 			 - new index length: 58176
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 118
# 			 - old index length: 53891,
# 			 - new index length: 55296
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 119
# 			 - old index length: 57756,
# 			 - new index length: 58753
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 12
# 			 - old index length: 55049,
# 			 - new index length: 56610
# 2025-11-27T18:54:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 120
# 			 - old index length: 56092,
# 			 - new index length: 58176
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 121
# 			 - old index length: 52722,
# 			 - new index length: 56400
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 122
# 			 - old index length: 53363,
# 			 - new index length: 56444
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 123
# 			 - old index length: 53488,
# 			 - new index length: 54720
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 124
# 			 - old index length: 48713,
# 			 - new index length: 58267
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 125
# 			 - old index length: 51377,
# 			 - new index length: 54191
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 126
# 			 - old index length: 55830,
# 			 - new index length: 56857
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 127
# 			 - old index length: 39300,
# 			 - new index length: 58465
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 128
# 			 - old index length: 54722,
# 			 - new index length: 56633
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 129
# 			 - old index length: 52986,
# 			 - new index length: 57024
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 13
# 			 - old index length: 56666,
# 			 - new index length: 57890
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 130
# 			 - old index length: 55240,
# 			 - new index length: 56544
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 131
# 			 - old index length: 55459,
# 			 - new index length: 58256
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 132
# 			 - old index length: 55020,
# 			 - new index length: 56342
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 133
# 			 - old index length: 56130,
# 			 - new index length: 57312
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 134
# 			 - old index length: 56821,
# 			 - new index length: 58435
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 135
# 			 - old index length: 54937,
# 			 - new index length: 56290
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 136
# 			 - old index length: 50626,
# 			 - new index length: 56302
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 137
# 			 - old index length: 55717,
# 			 - new index length: 56737
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 138
# 			 - old index length: 54361,
# 			 - new index length: 56485
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 139
# 			 - old index length: 53558,
# 			 - new index length: 56530
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 14
# 			 - old index length: 53667,
# 			 - new index length: 55009
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 140
# 			 - old index length: 55679,
# 			 - new index length: 58242
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 141
# 			 - old index length: 50682,
# 			 - new index length: 56441
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 142
# 			 - old index length: 56141,
# 			 - new index length: 57599
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 143
# 			 - old index length: 54809,
# 			 - new index length: 56712
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 144
# 			 - old index length: 52789,
# 			 - new index length: 54982
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 145
# 			 - old index length: 57548,
# 			 - new index length: 58753
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 146
# 			 - old index length: 36220,
# 			 - new index length: 58263
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 147
# 			 - old index length: 56844,
# 			 - new index length: 58753
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 148
# 			 - old index length: 55837,
# 			 - new index length: 57312
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 149
# 			 - old index length: 52824,
# 			 - new index length: 56771
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 15
# 			 - old index length: 53878,
# 			 - new index length: 55872
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 150
# 			 - old index length: 51029,
# 			 - new index length: 54178
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 151
# 			 - old index length: 56583,
# 			 - new index length: 58011
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 152
# 			 - old index length: 50085,
# 			 - new index length: 55054
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 153
# 			 - old index length: 54941,
# 			 - new index length: 56161
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 154
# 			 - old index length: 53949,
# 			 - new index length: 56648
# 2025-11-27T18:54:07 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:07 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:07 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:07 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 155
# 			 - old index length: 55268,
# 			 - new index length: 57024
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 156
# 			 - old index length: 54632,
# 			 - new index length: 56585
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 157
# 			 - old index length: 52022,
# 			 - new index length: 56313
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 158
# 			 - old index length: 52509,
# 			 - new index length: 54433
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 159
# 			 - old index length: 54574,
# 			 - new index length: 55872
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 16
# 			 - old index length: 51306,
# 			 - new index length: 55441
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 160
# 			 - old index length: 48941,
# 			 - new index length: 56737
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 161
# 			 - old index length: 54669,
# 			 - new index length: 58025
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 162
# 			 - old index length: 53945,
# 			 - new index length: 56737
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 163
# 			 - old index length: 53157,
# 			 - new index length: 56737
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 164
# 			 - old index length: 52904,
# 			 - new index length: 57656
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 165
# 			 - old index length: 53150,
# 			 - new index length: 56161
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 166
# 			 - old index length: 55752,
# 			 - new index length: 57516
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 167
# 			 - old index length: 55273,
# 			 - new index length: 56448
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 168
# 			 - old index length: 56066,
# 			 - new index length: 57883
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 169
# 			 - old index length: 57555,
# 			 - new index length: 58464
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 17
# 			 - old index length: 53115,
# 			 - new index length: 56345
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 170
# 			 - old index length: 46297,
# 			 - new index length: 57484
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 171
# 			 - old index length: 54984,
# 			 - new index length: 57711
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 18
# 			 - old index length: 51793,
# 			 - new index length: 56736
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 19
# 			 - old index length: 56545,
# 			 - new index length: 58464
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 2
# 			 - old index length: 53537,
# 			 - new index length: 58269
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 20
# 			 - old index length: 50971,
# 			 - new index length: 56263
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 21
# 			 - old index length: 52428,
# 			 - new index length: 57372
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 22
# 			 - old index length: 57656,
# 			 - new index length: 58633
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 23
# 			 - old index length: 56541,
# 			 - new index length: 58739
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 24
# 			 - old index length: 54175,
# 			 - new index length: 56404
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 25
# 			 - old index length: 54723,
# 			 - new index length: 56161
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 26
# 			 - old index length: 54422,
# 			 - new index length: 56334
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 27
# 			 - old index length: 55011,
# 			 - new index length: 56159
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 28
# 			 - old index length: 55940,
# 			 - new index length: 58082
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 29
# 			 - old index length: 53841,
# 			 - new index length: 56159
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 3
# 			 - old index length: 57599,
# 			 - new index length: 58752
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 30
# 			 - old index length: 51828,
# 			 - new index length: 58327
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 31
# 			 - old index length: 52843,
# 			 - new index length: 55585
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 32
# 			 - old index length: 55283,
# 			 - new index length: 57888
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 34
# 			 - old index length: 55527,
# 			 - new index length: 57487
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:08 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 35
# 			 - old index length: 50586,
# 			 - new index length: 56449
# 2025-11-27T18:54:08 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:08 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:08 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 36
# 			 - old index length: 52320,
# 			 - new index length: 58272
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 37
# 			 - old index length: 57064,
# 			 - new index length: 58463
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 38
# 			 - old index length: 56440,
# 			 - new index length: 58175
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 39
# 			 - old index length: 54032,
# 			 - new index length: 56763
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 4
# 			 - old index length: 48805,
# 			 - new index length: 56302
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 40
# ...
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:09 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 67
# 			 - old index length: 51334,
# 			 - new index length: 55738
# 2025-11-27T18:54:09 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:09 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:09 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 68
# 			 - old index length: 54684,
# 			 - new index length: 243936
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 69
# 			 - old index length: 55773,
# 			 - new index length: 56737
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 7
# 			 - old index length: 54957,
# 			 - new index length: 57890
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 70
# 			 - old index length: 56511,
# 			 - new index length: 58751
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 71
# 			 - old index length: 55164,
# 			 - new index length: 57712
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 72
# 			 - old index length: 56670,
# 			 - new index length: 58465
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 73
# 			 - old index length: 52905,
# 			 - new index length: 55601
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 74
# 			 - old index length: 55306,
# 			 - new index length: 58562
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 75
# 			 - old index length: 57391,
# 			 - new index length: 58466
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 76
# 			 - old index length: 48953,
# 			 - new index length: 54232
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 77
# 			 - old index length: 55273,
# 			 - new index length: 57427
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 78
# 			 - old index length: 53008,
# 			 - new index length: 57025
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 79
# 			 - old index length: 53153,
# 			 - new index length: 57594
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 8
# 			 - old index length: 51533,
# 			 - new index length: 52888
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 80
# 			 - old index length: 55549,
# 			 - new index length: 58176
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 81
# 			 - old index length: 54463,
# 			 - new index length: 56492
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 82
# 			 - old index length: 46006,
# 			 - new index length: 56307
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 83
# 			 - old index length: 52967,
# 			 - new index length: 56160
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 85
# 			 - old index length: 52649,
# 			 - new index length: 54884
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 86
# 			 - old index length: 54078,
# 			 - new index length: 56736
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 87
# 			 - old index length: 55462,
# 			 - new index length: 56161
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 88
# 			 - old index length: 54484,
# 			 - new index length: 56336
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 89
# 			 - old index length: 47386,
# 			 - new index length: 57889
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 9
# 			 - old index length: 44932,
# 			 - new index length: 56518
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 90
# 			 - old index length: 55186,
# 			 - new index length: 56449
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 91
# 			 - old index length: 56521,
# 			 - new index length: 57311
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 92
# 			 - old index length: 54214,
# 			 - new index length: 55924
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 93
# 			 - old index length: 52359,
# 			 - new index length: 55009
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 94
# 			 - old index length: 56890,
# 			 - new index length: 58765
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:10 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 95
# 			 - old index length: 54745,
# 			 - new index length: 56515
# 2025-11-27T18:54:10 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:10 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:10 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:11 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 96
# 			 - old index length: 51301,
# 			 - new index length: 55297
# 2025-11-27T18:54:11 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:11 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:11 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:11 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 97
# 			 - old index length: 52595,
# 			 - new index length: 57019
# 2025-11-27T18:54:11 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:11 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:11 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:11 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 98
# 			 - old index length: 56576,
# 			 - new index length: 57456
# 2025-11-27T18:54:11 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:54:11 - 	Most common time interval: 5 minutes
# 2025-11-27T18:54:11 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:54:11 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 99
# 			 - old index length: 54752,
# 			 - new index length: 56737

# %%
# Test on single patient first
test_patient = list(patient_dict.keys())[0]
test_df = patient_dict[test_patient]

print(f"Before: {len(test_df)} rows")
processed_test, freq = ensure_regular_time_intervals_with_aggregation(test_df)
print(f"After: {len(processed_test)} rows")
print(f"Frequency: {freq} min")
# Out:
# 2025-11-27T18:56:06 - ensure_regular_time_intervals_with_aggregation(): Ensuring regular time intervals with aggregation...
# 2025-11-27T18:56:06 - 	Most common time interval: 5 minutes
# 2025-11-27T18:56:06 - 	Aggregation strategy: {'p_num': 'first', 'period': 'first', 'bg_mgdL': 'sum', 'bg_mM': 'mean'}
# 2025-11-27T18:56:06 - Post-ensure_regular_time_intervals_with_aggregation():
# 			Patient 1.0
# 			 - old index length: 58465,
# 			 - new index length: 58465
# Before: 58465 rows
# After: 58465 rows
# Frequency: 5 min

# %%
test_df.head()
# Out:
#                      p_num       period  bg_mgdL     bg_mM
# datetime
# 2017-12-12 00:00:00    1.0  1. Baseline    172.0  9.555556
# 2017-12-12 00:05:00    1.0  1. Baseline    170.0  9.444444
# 2017-12-12 00:10:00    1.0  1. Baseline    167.0  9.277778
# 2017-12-12 00:15:00    1.0  1. Baseline    163.0  9.055556
# 2017-12-12 00:20:00    1.0  1. Baseline    160.0  8.888889

# %%
# Pick a patient to analyze
test_pid = 89

# Get original and processed
original_df = split_multipatient_dataframe(cgm_df, patient_col="p_num")[test_pid]
processed_df = patient_dict[test_pid]

print(f"Original: {len(original_df)} rows")
print(f"Processed: {len(processed_df)} rows")
print(f"Added rows: {len(processed_df) - len(original_df)} (these are NaN-filled gaps)")

# Find the NEW timestamps (gaps that were filled)
original_timestamps = set(original_df.index)
processed_timestamps = set(processed_df.index)

new_timestamps = processed_timestamps - original_timestamps
print(f"\nNew timestamps added: {len(new_timestamps)}")
# Out:
# Original: 47386 rows
# Processed: 57889 rows
# Added rows: 10503 (these are NaN-filled gaps)
#
# New timestamps added: 57550

# %%
for ts in sorted(list(new_timestamps))[:5]:
    print(ts)
    print(processed_df.loc[ts])
# Out:
# 2018-04-16 00:00:00
# p_num             89.0
# period     1. Baseline
# bg_mgdL          112.0
# bg_mM         6.222222
# Name: 2018-04-16 00:00:00, dtype: object
# 2018-04-16 00:05:00
# p_num             89.0
# period     1. Baseline
# bg_mgdL          110.0
# bg_mM         6.111111
# Name: 2018-04-16 00:05:00, dtype: object
# 2018-04-16 00:10:00
# p_num             89.0
# period     1. Baseline
# bg_mgdL          107.0
# bg_mM         5.944444
# Name: 2018-04-16 00:10:00, dtype: object
# 2018-04-16 00:15:00
# p_num             89.0
# period     1. Baseline
# bg_mgdL          102.0
# bg_mM         5.666667
# Name: 2018-04-16 00:15:00, dtype: object
# 2018-04-16 00:20:00
# p_num             89.0
# period     1. Baseline
# bg_mgdL           97.0
# bg_mM         5.388889
# Name: 2018-04-16 00:20:00, dtype: object

# %%
# Pick a patient
test_pid = 89
original_df = split_multipatient_dataframe(cgm_df, patient_col="p_num")[test_pid]
processed_df = patient_dict[test_pid]

# Round original timestamps to same 5-min grid (mimicking what the function does)
freq = 5  # minutes
original_rounded = original_df.index.round(f"{freq}min")

# Now compare properly
original_bins = set(original_rounded)
processed_bins = set(processed_df.index)

# TRUE new timestamps (gaps that were filled)
truly_new = processed_bins - original_bins

print(f"Original timestamps: {len(original_df)}")
print(f"Original unique bins (after rounding): {len(original_bins)}")
print(f"Processed timestamps: {len(processed_df)}")
print(f"Truly NEW timestamps (gap fills): {len(truly_new)}")
# Out:
# Original timestamps: 47386
# Original unique bins (after rounding): 47386
# Processed timestamps: 57889
# Truly NEW timestamps (gap fills): 10503

# %%
# Create a df with the rounded original timestamps
original_with_bins = original_df.copy()
original_with_bins["rounded_ts"] = original_with_bins.index.round(f"{freq}min")
original_with_bins = original_with_bins.reset_index().rename(
    columns={"datetime": "original_ts"}
)

# Reset processed for merge
processed_reset = processed_df.reset_index().rename(columns={"datetime": "grid_ts"})

# Left join: all processed timestamps, match with original where exists
merged = processed_reset.merge(
    original_with_bins[["rounded_ts", "original_ts", "bg_mM"]].rename(
        columns={"bg_mM": "original_bg"}
    ),
    left_on="grid_ts",
    right_on="rounded_ts",
    how="left",
    indicator=True,  # Adds column showing match status
)

# Show the breakdown
print("Merge result:")
print(merged["_merge"].value_counts())

# The "left_only" rows are the GAP FILLS
gap_fills = merged[merged["_merge"] == "left_only"]
print(f"\n Gap fills (new rows): {len(gap_fills)}")
print(" These should have NaN bg_mM:")
print(gap_fills[["grid_ts", "bg_mM", "original_bg", "_merge"]].head(20))

# Verify ALL gap fills have NaN
print(f"\n✓ All gap fills have NaN bg_mM: {gap_fills['bg_mM'].isna().all()}")
# Out:
# Merge result:
# _merge
# both          47386
# left_only     10503
# right_only        0
# Name: count, dtype: int64
#
#  Gap fills (new rows): 10503
#  These should have NaN bg_mM:
#                grid_ts  bg_mM  original_bg     _merge
# 35 2018-04-16 02:55:00    NaN          NaN  left_only
# 36 2018-04-16 03:00:00    NaN          NaN  left_only
# 37 2018-04-16 03:05:00    NaN          NaN  left_only
# 38 2018-04-16 03:10:00    NaN          NaN  left_only
# 39 2018-04-16 03:15:00    NaN          NaN  left_only
# 40 2018-04-16 03:20:00    NaN          NaN  left_only
# 41 2018-04-16 03:25:00    NaN          NaN  left_only
# 42 2018-04-16 03:30:00    NaN          NaN  left_only
# 43 2018-04-16 03:35:00    NaN          NaN  left_only
# 44 2018-04-16 03:40:00    NaN          NaN  left_only
# 45 2018-04-16 03:45:00    NaN          NaN  left_only
# 46 2018-04-16 03:50:00    NaN          NaN  left_only
# 47 2018-04-16 03:55:00    NaN          NaN  left_only
# 48 2018-04-16 04:00:00    NaN          NaN  left_only
# 49 2018-04-16 04:05:00    NaN          NaN  left_only
# 50 2018-04-16 04:10:00    NaN          NaN  left_only
# 51 2018-04-16 04:15:00    NaN          NaN  left_only
# 52 2018-04-16 04:20:00    NaN          NaN  left_only
# 53 2018-04-16 04:25:00    NaN          NaN  left_only
# 54 2018-04-16 04:30:00    NaN          NaN  left_only
#
# ✓ All gap fills have NaN bg_mM: True
