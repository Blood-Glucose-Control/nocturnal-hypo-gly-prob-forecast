# %%
import pandas as pd

# Chunked conversion for huge files
chunks = pd.read_csv(
    "/data/home/cjrisi/nocturnal/cache/data/gluroo_2026/raw/readings-2025-01-01.csv",
    chunksize=100_000,
)

# %%
df1 = next(chunks)

# %%
df1
# Out:
#                               gid                        date  bgl  \
# 0      s9goVCD74Ud1sMMLybh1avu1Eo      2025-01-24 11:03:40+00  112
# 1      9z4qEsDB9XHL5GecFmPphlLnf0      2025-01-24 11:03:40+00  125
# 2      ba1ZIhB0Jpys3NP2j0cRcas5yX  2025-01-24 11:03:13.374+00  147
# 3      RhgC54sKeTRjnjOstk9KJzvaH8      2025-01-24 11:03:41+00  172
# 4      veDpfUgm82Czdp4ISbcN2jUn73   2025-01-12 08:00:09.24+00  119
# ...                           ...                         ...  ...
# 99995  kS5bUloog2JTrK4u9rGAtT8bb9  2025-01-12 08:05:11.997+00  136
# 99996  jXopQz30TblT+BtewbEIOWCujy      2025-01-18 05:40:12+00  131
# 99997  NcLVdf7cSpex8eBBiZb1nts8b5  2025-01-12 08:05:15.195+00  315
# 99998  e66SMD1lnmi/5C9M/wWwlxb5q4      2025-01-18 05:39:24+00  142
# 99999  SuD8F16mtPevvQr4JjWLaXXigv  2025-01-12 08:05:18.096+00  123
#
#               trend
# 0              FLAT
# 1              FLAT
# 2              FLAT
# 3              FLAT
# 4              FLAT
# ...             ...
# ...
